# %% [markdown]
# <a href="https://colab.research.google.com/github/kellianneyang/project-exploration/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Grades Project: Data Cleaning

# %% [markdown]
# This notebook continues the work begun in the previous notebook for this project, where all .csv files associated with this dataset were merged.

# %% [markdown]
# The goal of this notebook is to prepare data for machine learning preprocessing. We would like to understand the data and understand what we want from the data.
#
# This notebook will:
# - Create new columns as necessary and delete columns as necessary (preliminary feature engineering)
# - Identify possible target variables
# - Delete any rows from the dataframes that do not have values for the target variables
# - Delete any duplicated rows
# - Inspect missing values (missing values will NOT be imputed; this will be left for machine learning preprocessing)
# - Identify outliers

# %% [markdown]
# ## Overview

# %% [markdown]
# To use the data provided in this dataset (https://www.kaggle.com/datasets/Madgrades/uw-madison-courses), which is provided in multiple .csv files, for a machine learning model, we will need to merge the files to create one .csv file.

# %% [markdown]
# ## .csv files and columns
#
# Included in dataset as separate .csv files:
# - schedules.csv: each row is a unique potential schedule
#     - (schedule) uuid: unique identifier of schedules
#     - start_time: start of class, in minutes
#     - end_time: end of class, in minutes (drop -- high co-linearity with start_time)
#     - mon: boolean, if class meets on monday
#     - tues: "
#     - wed: "
#     - thurs: "
#     - fri: "
#     - sat: "
#     - sun: "
#       - sat and sun have very few values; combine to get more observations
# - subjects.csv: each row is a unique subject
#     - (subject) code: 3-digit unique identifier of subjects
#     - (subject) name: name of subject
#     - (subject) abbreviation: abbreviation (e.g. ENGL for English)
# - teachings.csv: each row is a unique instructor
#     - instructor_id: numeric unique identifier of instructor
#     - section_uuid: section taught by instructor
# - subject_memberships.csv: each row is a course offering (course offered in certain term; does not encompass all sections in that term)
#     - subject_code: subject code associated with course offering
#     - course_offering_uuid: unique identifier of course offerings
# - sections.csv: each row is a section (specific instance of course at certain time in certain place in certain term)
#     - (section) uuid: unique identifier of section (alphanumeric)
#       - could have multiple section uuids for cross-listed sections
#     - course_offering_uuid: unique identifier of course offering (course offered in certain term but encompasses all sections in that term)
#     - section_type: 3-letter identifier (e.g., LEC for lecture)
#     - (section) number: 1-3-number of section (e.g., 301 for section 301)
#     - room_uuid: unique identifier of room and building where section is held (including online and off-campus designations)
#     - schedule_uuid: unique identifier of schedule for section
# - rooms.csv: each row is a specific place
#     - (room) uuid: unique identifier of building and room (inclduing off-campus and online)
#     - facility_code: unique identifier of building
#     - room_code: number of room within a building
# - instructors.csv (will not use -- is essentially a duplicate of teachings; can use to look up instructors' names): each row is an instructor
#     - (instructor) id: unique identifier of instructor
#     - (instructor) name: instructor's name
# - grade_distributions.csv: each row is a section's grades
#     - course_offering_uuid: identifies the course offering (certain course in certain term, but not broken down into sections)
#     - section_number: number of section for grades
#     - a_count: number of As
#     - ab_count: number of ABs (can be combined with As as needed)
#     - b_count: number of Bs
#     - bc_count: number of BCs (can be combined with Bs as needed)
#     - c_count: number of Cs
#     - d_count: number of Ds
#     - f_count: number of Fs
#     - s_count: satisfactory
#     - u_count: unstatisfactory
#     - cr_count: credit
#     - n_count: no credit
#     - p_count
#     - i_count: incomplete
#     - nw_count: no work
#     - nr_count
# - course_offerings.csv: each row is a course offering (course offered in certain term)
#     - (course offering) uuid: unique identifier of course offering
#     - course_uuid: course that the course offering belongs to
#     - term_code: academic term when course offering was held
#     - (course offering) name: name associate with course offering (can be different than course name)
# - courses.csv: each row is a course (abstract; not associated with specific course offering)
#     - (course) uuid: uniquely identifies the course
#     - (course) name: name of course
#     - (course) number: number in course catalog (e.g. 101 for ENGL 101)

# %% [markdown]
# ## Feature variables

# %% [markdown]
# This dataset is large and has many variables we can choose from as our feature variables.
#
# Many of the variables have a large number of unique values (high-cardinality), so we may have to drop those for our machine learning algorithm to be able to predict some variance.
#
# We will also be combining some columns and dropping some columns for various reasons.

# %% [markdown]
# ## Target variables

# %% [markdown]
# We are interested in whether the feature variables can predict variation in grades. There are many grade types given (see source: https://guide.wisc.edu/undergraduate/#enrollmentandrecordstext), but to keep the problem manageable, we will narrow down the target grades.
#
# We will instantiate the following target variables and see if machine learning algorithms can predict the variation in any of them.
#
# 1. Proportion of A grades given (of all grades given)
# 2. Proportion of F grades given (of all grades given)
# 3. Average letter grade given (letter grades: A, AB, B, BC, C, D, and F)
# 4. Number of grades given

# %% [markdown]
# # Preliminary Steps

# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# load data
path = 'Data/all_grades_data.csv'
df = pd.read_csv(path, low_memory = False, index_col = 0)

# %%
# inspect
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162710 entries, 0 to 162709
# Data columns (total 43 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   section_uuid          162710 non-null  object
#  1   course_offering_uuid  162710 non-null  object
#  2   section_type          162710 non-null  object
#  3   section_number        162710 non-null  float64
#  4   room_uuid             66778 non-null   object
#  5   schedule_uuid         162710 non-null  object
#  6   instructor_id         162682 non-null  float64
#  7   facility_code         66778 non-null   object
#  8   room_code             64871 non-null   object
#  9   start_time            162710 non-null  float64
#  10  end_time              162710 non-null  float64
#  11  mon                   162710 non-null  bool
#  12  tues                  162710 non-null  bool
#  13  wed                   162710 non-null  bool
#  14  thurs                 162710 non-null  bool
#  15  fri                   162710 non-null  bool
#  16  sat                   162710 non-null  bool
#  17  sun                   162710 non-null  bool
#  18  subject_code          162710 non-null  int64
#  19  subject_name          162710 non-null  object
#  20  subject_abbreviation  162710 non-null  object
#  21  course_uuid           162710 non-null  object
#  22  term_code             162710 non-null  float64
#  23  course_offering_name  162710 non-null  object
#  24  course_name           162710 non-null  object
#  25  course_number         162710 non-null  float64
#  26  course_and_section    162710 non-null  object
#  27  a_count               162710 non-null  int64
#  28  ab_count              162710 non-null  int64
#  29  b_count               162710 non-null  int64
#  30  bc_count              162710 non-null  int64
#  31  c_count               162710 non-null  int64
#  32  d_count               162710 non-null  int64
#  33  f_count               162710 non-null  int64
#  34  s_count               162710 non-null  int64
#  35  u_count               162710 non-null  int64
#  36  cr_count              162710 non-null  int64
#  37  n_count               162710 non-null  int64
#  38  p_count               162710 non-null  int64
#  39  i_count               162710 non-null  int64
#  40  nw_count              162710 non-null  int64
#  41  nr_count              162710 non-null  int64
#  42  other_count           162710 non-null  int64
# dtypes: bool(7), float64(6), int64(17), object(13)
# memory usage: 47.0+ MB

# %%
# inspect
df.sample(10)
# Out:
#                                 section_uuid  \
# 19009   cbac306d-f905-3ccf-9f7d-5f9442a05539
# 67790   84512989-316c-370c-8a33-cbcb3791af02
# 146834  423a07c3-e408-3393-a49a-a111afd3b09a
# 53460   c8ec9106-9201-39bc-8b25-9d17fe26c258
# 7473    c4bf5d98-1b37-3db8-ba2e-0f5d9e6cdbbd
# 111218  84e04fef-e9aa-3ef0-bdbd-8d2d33911437
# 112170  2d0c4512-003c-30f2-ac98-9ba2e4c68b21
# 121255  c3d9fa16-5f13-37b1-b3ce-60b495b8774f
# 162679  9931e0c5-af09-39b4-b84c-c4f0613342c9
# 378     1c29cc4f-bf9e-3964-8a12-dff96686ef17
#
#                         course_offering_uuid section_type  section_number  \
# 19009   d9a497db-6a2b-394b-ae5a-1291819c7de9          ind            60.0
# 67790   fa7e9a07-ec4d-3e31-b376-d8bb0a0b47b0          ind            16.0
# 146834  3412570c-4052-3744-ad0c-08c78215ec87          lab             1.0
# 53460   717e506e-cff5-3c6e-8b03-d64a68ff0597          sem             8.0
# 7473    45d4b00e-152d-3149-8cfe-32b07c6c7be8          lec             1.0
# 111218  1d938124-07f8-3c8c-a499-ebcb7e22b530          lec             1.0
# 112170  47056cc9-dc99-3a60-9df5-1bea8b3a6ce8          lec             1.0
# 121255  d48cd389-a77f-385b-a29a-47e2e16fff8a          lec             1.0
# 162679  ccf20fd7-a0f0-390e-82c8-3a268ce70881          lec             1.0
# 378     78a11bde-275c-313a-9c65-ea93faacdeba          lec            31.0
#
#                                    room_uuid  \
# 19009                                    NaN
# 67790                                    NaN
# 146834  53ee561a-3e94-310a-9d6d-201601a27306
# 53460                                    NaN
# 7473    f11d9506-23cd-3052-b1fa-e7261a80add7
# 111218  6c0b393c-8208-34a0-bb41-4b4ec8292357
# 112170  ce8bbeed-5bf1-3044-b7f1-3310d5d99e58
# 121255  b3435a89-719a-3ef1-a73b-9f26dede8e56
# 162679  f6a4c14e-6c1c-38db-8966-031c10958892
# 378     b245416a-1cb2-3cd6-919c-4bde53be2155
#
#                                schedule_uuid  instructor_id facility_code  \
# 19009   f2d66a4d-0c08-3b48-abf6-649fffd7ae90      2601315.0           NaN
# 67790   f2d66a4d-0c08-3b48-abf6-649fffd7ae90      2601570.0           NaN
# 146834  2aaa8364-5590-3985-b39e-edaf597d0f8f      4955455.0          0469
# 53460   f2d66a4d-0c08-3b48-abf6-649fffd7ae90      2601560.0           NaN
# 7473    bcf762ed-780b-3bef-a285-c743f06cbe28      2601971.0          0118
# 111218  3f78e049-8448-355b-b5a0-725b0f85f1d1      1016452.0          0046
# 112170  f273853e-fa6d-38ba-8707-63bb7d16d8cd      4113134.0          0482
# 121255  22b99e69-ae34-3577-bf01-899774ba3047       164464.0          0408
# 162679  40d52ac7-8397-3157-9fad-bf4f923ab555      4194092.0          0476
# 378     b8f8227d-d5bb-35a8-b903-d3213ede8a00      5514889.0          0545
#
#        room_code  start_time  ...  f_count  s_count  u_count  cr_count  \
# 19009        NaN        -1.0  ...        0        0        0         0
# 67790        NaN        -1.0  ...        0        0        0         0
# 146834      7451       990.0  ...        0        0        0         0
# 53460        NaN        -1.0  ...        0        0        0         0
# 7473        0128       900.0  ...        0        0        0         0
# 111218      6102       480.0  ...        2        0        0         0
# 112170      0378       870.0  ...        0        0        0         0
# 121255      2534       595.0  ...        2        1        0         0
# 162679      0245       480.0  ...        0        0        0         0
# 378         4018       725.0  ...        0        0        0         0
#
#         n_count  p_count  i_count  nw_count  nr_count other_count
# 19009         0        0        0         0         0           0
# 67790         0        0        0         0         0           0
# 146834        0        0        0         0         0           0
# 53460         0        0        0         0         0           0
# 7473          0        0        0         0         0           0
# 111218        0        0        0         0         0           0
# 112170        0        0        0         0         0           0
# 121255        0        0        0         0         0           0
# 162679        0        0        0         0         0           0
# 378           0        0        0         0         0           0
#
# [10 rows x 43 columns]

# %%
# inspect
df.columns
# Out:
# Index(['section_uuid', 'course_offering_uuid', 'section_type',
#        'section_number', 'room_uuid', 'schedule_uuid', 'instructor_id',
#        'facility_code', 'room_code', 'start_time', 'end_time', 'mon', 'tues',
#        'wed', 'thurs', 'fri', 'sat', 'sun', 'subject_code', 'subject_name',
#        'subject_abbreviation', 'course_uuid', 'term_code',
#        'course_offering_name', 'course_name', 'course_number',
#        'course_and_section', 'a_count', 'ab_count', 'b_count', 'bc_count',
#        'c_count', 'd_count', 'f_count', 's_count', 'u_count', 'cr_count',
#        'n_count', 'p_count', 'i_count', 'nw_count', 'nr_count', 'other_count'],
#       dtype='object')

# %% [markdown]
# # Grades

# %% [markdown]
# Information from the University of Wisconsin's website about grades can be found here: https://guide.wisc.edu/undergraduate/#enrollmentandrecordstext
#
# Grades:
# - a, ab, b, bc, c, d, f - letter grades
#   - ab - intermediate grade between a and b
#   - bc - intermediate grade between b and c
# - s - satisfactory, used in pass/fail courses
# - u - unsatisfactory, used in pass/fail courses
# - cr - credit, used in credit/no credit courses
# - n - no credit, used in credit/no credit courses
# - p - progress: temporary grade used for courses extending beyond one term
# - i - incomplete: temporary grade used when work is not completed during a term
# - nw - no work: for students who enroll in a course and then never attend
# - nr - no report: a grade was not submitted by the instructor
# - other - any one of several other grading codes

# %%
# for every row
for i in range(len(df)):

    # create counts of all grades
    num_a = df.at[i, 'a_count']
    num_f = df.at[i, 'f_count']
    num_a = df.at[i, 'a_count']
    num_ab = df.at[i, 'ab_count']
    num_b = df.at[i, 'b_count']
    num_bc = df.at[i, 'bc_count']
    num_c = df.at[i, 'c_count']
    num_d = df.at[i, 'd_count']
    num_f = df.at[i, 'f_count']
    num_s = df.at[i, 's_count']
    num_u = df.at[i, 'u_count']
    num_cr = df.at[i, 'cr_count']
    num_n = df.at[i, 'n_count']
    num_p = df.at[i, 'p_count']
    num_i = df.at[i, 'i_count']
    num_nw = df.at[i, 'nw_count']
    num_nr = df.at[i, 'nr_count']
    num_other = df.at[i, 'other_count']
    
    # calculate number of letter grades
    num_letter_grades = (num_a + num_ab + num_b + num_bc + num_c + num_d + 
                         num_f)
    
    # if there are letter grades
    if num_letter_grades != 0:
        
        # calculate the average grade and store
        avg_letter_grade = ((num_a * 4.0) + 
                            (num_ab * 3.5) + 
                            (num_b * 3.0) +
                            (num_bc * 2.5) + 
                            (num_c * 2.0) + 
                            (num_d * 1.0)) / num_letter_grades

        df.at[i, 'avg_letter_grade'] = avg_letter_grade

    # calculate number of all grades
    num_all_grades = (num_a + num_ab + num_b + num_bc + num_c + num_d + 
                      num_f + num_s + num_u + num_cr + num_n + num_p + 
                      num_i + num_nw + num_nr + num_other)
    
    # create column for num_all_grades to easily be able to delete courses 
    # where no grades were recorded
    df.at[i, 'num_all_grades'] = num_all_grades

    # if num_all_grades is not 0 (we want to exclude rows where there are no 
    # recorded grades)
    if num_all_grades != 0:

        # calculate and store proportions
        a_proportion = (num_a) / (num_all_grades)
        df.at[i, 'a_proportion'] = a_proportion
        
        ab_proportion = (num_ab) / (num_all_grades)
        df.at[i, 'ab_proportion'] = ab_proportion
        
        b_proportion = (num_b) / (num_all_grades)
        df.at[i, 'b_proportion'] = b_proportion
        
        bc_proportion = (num_bc) / (num_all_grades)
        df.at[i, 'bc_proportion'] = bc_proportion
        
        c_proportion = (num_c) / (num_all_grades)
        df.at[i, 'c_proportion'] = c_proportion
        
        d_proportion = (num_d) / (num_all_grades)
        df.at[i, 'd_proportion'] = d_proportion
        
        f_proportion = (num_f) / (num_all_grades)
        df.at[i, 'f_proportion'] = f_proportion
        
        s_proportion = (num_s) / (num_all_grades)
        df.at[i, 's_proportion'] = s_proportion
        
        u_proportion = (num_u) / (num_all_grades)
        df.at[i, 'u_proportion'] = u_proportion
        
        cr_proportion = (num_cr) / (num_all_grades)
        df.at[i, 'cr_proportion'] = cr_proportion
        
        n_proportion = (num_n) / (num_all_grades)
        df.at[i, 'n_proportion'] = n_proportion
        
        p_proportion = (num_p) / (num_all_grades)
        df.at[i, 'p_proportion'] = p_proportion
        
        i_proportion = (num_i) / (num_all_grades)
        df.at[i, 'i_proportion'] = i_proportion
        
        nw_proportion = (num_nw) / (num_all_grades)
        df.at[i, 'nw_proportion'] = nw_proportion
        
        nr_proportion = (num_nr) / (num_all_grades)
        df.at[i, 'nr_proportion'] = nr_proportion
        
        other_proportion = (num_other) / (num_all_grades)
        df.at[i, 'other_proportion'] = other_proportion

# %%
# check
df[['a_proportion', 'ab_proportion', 'b_proportion', 'bc_proportion', \
    'c_proportion', 'd_proportion', 'f_proportion', 's_proportion', \
    'u_proportion', 'cr_proportion', 'n_proportion', 'p_proportion', \
    'i_proportion', 'nw_proportion', 'nr_proportion', 'other_proportion', \
    'num_all_grades', 'avg_letter_grade']]
# Out:
#         a_proportion  ab_proportion  b_proportion  bc_proportion  \
# 0                NaN            NaN           NaN            NaN
# 1                NaN            NaN           NaN            NaN
# 2                NaN            NaN           NaN            NaN
# 3                NaN            NaN           NaN            NaN
# 4                NaN            NaN           NaN            NaN
# ...              ...            ...           ...            ...
# 162705       0.22500       0.237500      0.312500         0.1125
# 162706           NaN            NaN           NaN            NaN
# 162707           NaN            NaN           NaN            NaN
# 162708       0.52381       0.238095      0.047619         0.0000
# 162709           NaN            NaN           NaN            NaN
#
#         c_proportion  d_proportion  f_proportion  s_proportion  u_proportion  \
# 0                NaN           NaN           NaN           NaN           NaN
# 1                NaN           NaN           NaN           NaN           NaN
# 2                NaN           NaN           NaN           NaN           NaN
# 3                NaN           NaN           NaN           NaN           NaN
# 4                NaN           NaN           NaN           NaN           NaN
# ...              ...           ...           ...           ...           ...
# 162705        0.0375        0.0625      0.012500      0.000000           0.0
# 162706           NaN           NaN           NaN           NaN           NaN
# 162707           NaN           NaN           NaN           NaN           NaN
# 162708        0.0000        0.0000      0.047619      0.142857           0.0
# 162709           NaN           NaN           NaN           NaN           NaN
#
#         cr_proportion  n_proportion  p_proportion  i_proportion  \
# 0                 NaN           NaN           NaN           NaN
# 1                 NaN           NaN           NaN           NaN
# 2                 NaN           NaN           NaN           NaN
# 3                 NaN           NaN           NaN           NaN
# 4                 NaN           NaN           NaN           NaN
# ...               ...           ...           ...           ...
# 162705            0.0           0.0           0.0           0.0
# 162706            NaN           NaN           NaN           NaN
# 162707            NaN           NaN           NaN           NaN
# 162708            0.0           0.0           0.0           0.0
# 162709            NaN           NaN           NaN           NaN
#
#         nw_proportion  nr_proportion  other_proportion  num_all_grades  \
# 0                 NaN            NaN               NaN             0.0
# 1                 NaN            NaN               NaN             0.0
# 2                 NaN            NaN               NaN             0.0
# 3                 NaN            NaN               NaN             0.0
# 4                 NaN            NaN               NaN             0.0
# ...               ...            ...               ...             ...
# 162705            0.0            0.0               0.0            80.0
# 162706            NaN            NaN               NaN             0.0
# 162707            NaN            NaN               NaN             0.0
# 162708            0.0            0.0               0.0            21.0
# 162709            NaN            NaN               NaN             0.0
#
#         avg_letter_grade
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 162705          3.087500
# 162706               NaN
# 162707               NaN
# 162708          3.583333
# 162709               NaN
#
# [162710 rows x 18 columns]

# %% [markdown]
# ## Drop courses with no grades

# %%
# check number of rows
df.shape
# Out:
# (162710, 61)

# %%
# check if any rows have null for 'num_all_grades'
df['num_all_grades'].isna().sum()
# Out:
# 0

# %%
# check number of courses with zero grades
len(df[df['num_all_grades'] == 0])
# Out:
# 94183

# %%
# drop courses with zero grades
df = df[df['num_all_grades'] != 0]

# check
df.shape
# Out:
# (68527, 61)

# %% [markdown]
# # 'term_code'
#
# The current 'term_code' column gives a 4-digit code indicating the term the course was offered in.

# %% [markdown]
# 'term_code':
# - first digit always 1 (21st century)
# - second two digits academic year (from 07 to 18; year that the academic year ends in summer)
# - fourth digit term (2 = fall, 4 = spring, 6 = summer)
#
# Source: https://kb.wisc.edu/registrar/117776

# %%
# inspect
df['term_code'].value_counts(dropna = False)
# data includes years '07' to '18' and only fall (2) and spring (4) terms
# Out:
# 1072.0    3301
# 1102.0    3241
# 1082.0    3240
# 1092.0    3235
# 1152.0    3215
# 1122.0    3184
# 1074.0    3182
# 1132.0    3146
# 1112.0    3134
# 1142.0    3125
# 1084.0    3116
# 1162.0    3103
# 1172.0    3102
# 1104.0    3071
# 1134.0    3048
# 1182.0    3045
# 1094.0    3045
# 1114.0    3035
# 1144.0    3018
# 1154.0    3002
# 1164.0    2972
# 1174.0    2967
# Name: term_code, dtype: int64

# %% [markdown]
# We will split 'term_code' into one column for year (numeric, 7-18) and one for term (nominal, fall or spring)

# %%
# reset index to iterate through
df.reset_index(drop = True, inplace = True)

# %%
# iterate through all rows in df
for row in range(len(df)):

    # make sure string is 4 or more characters long
    if len(df.loc[row, 'term_code'].astype(str)) >= 4:

        # assign 'year' as the middle two characters in the string
        df.loc[row, 'year'] = df.loc[row, 'term_code'].astype(str)[1:3]

        # if string ends in 2
        if df.loc[row, 'term_code'].astype(str)[3] == '2':

            # assign 'term' as 'fall'
            df.loc[row, 'term'] = 'fall'
  
        # else
        else:

            # assign 'term' as 'spring'
            df.loc[row, 'term'] = 'spring'

# %%
# check
print(df['year'].value_counts(dropna = False))
print()
print(df['term'].value_counts(dropna = False))
# Out:
# 07    6483
# 08    6356
# 10    6312
# 09    6280
# 15    6217
# 13    6194
# 11    6169
# 14    6143
# 16    6075
# 17    6069
# 12    3184
# 18    3045
# Name: year, dtype: int64
#
# fall      38071
# spring    30456
# Name: term, dtype: int64

# %%
# drop 'term_code' as it is now redundant
df = df.drop(columns = 'term_code')

# check
print('term_code' in df.columns)
# Out:
# False

# %% [markdown]
# # Rooms and buildings

# %% [markdown]
# Every room_uuid has a facility_code which indicates a building, and a room_code which indicates a room in the building. We will drop the room_code column because it is likely a high-cardinality variable, since there are many, many rooms on campus. We will keep the building (facility_code).

# %%
df.drop(columns = ['room_uuid', 'room_code'], inplace = True)

# check
print('room_uuid' in df.columns)
print('room_code' in df.columns)
# Out:
# False
# False

# %% [markdown]
# # Schedules

# %% [markdown]
# 'start_time' and 'end_time' will probably have a high degree of co-linearity due to many classes being on a fixed schedule. So, we can drop 'end_time'.
#
# But, we are interested in if the length of a class may explain some variance in the grades earned, so first we will calculate 'class_length'. 'class_length' will represent the length of the class in minutes on any day of the week that the class meets (if class meets from 9:00am to 9:50am on MWF, 'class_length' will be 50 minutes).

# %%
# 'class_length'
df['class_length'] = df['end_time'] - df['start_time']

# %%
# drop 'end_time'
df.drop(columns = 'end_time', inplace = True)

# check
'end_time' in df.columns
# Out:
# False

# %%
# reset index for further cleaning
df.reset_index(inplace = True, drop = True)

# %%
# drop 'schedule_uuid'; it correlates with the other schedule variables
df.drop(columns = 'schedule_uuid', inplace = True)

# check
'schedule_uuid' in df.columns
# Out:
# False

# %% [markdown]
# # Subjects
#
# Delete 'subject_abbreviations' and 'subject_codes', as these are repeats of the 'subject_name' column.

# %%
df.drop(columns = ['subject_code', 'subject_abbreviation'], inplace = True)

# check
print('subject_code' in df.columns)
print('subject_abbreviation' in df.columns)
# Out:
# False
# False

# %% [markdown]
# # Course number

# %% [markdown]
# The 'course_number' column includes numbers in the following ranges:
# - below 100: below college-level
# - 100-299: elementary (undergraduate students only)
# - 300-499: intermediate (grad & undergrad)
# - 500-699: advanced (grad & undergrad)
# - 700+: graduate students only
#
# Source: https://grad.wisc.edu/documents/course-numbering-system/
#
# We will split up the courses into these ranges to reduce the cardinality of the variable.
#
# We will drop the below college-level and graduate student only courses and retain just courses that are elementary, intermediate, or advanced, and that undergraduate students may take. (But we will wait until after merging with big_df to do so, so that we delete the other information for these courses as well.)

# %%
for i in range(len(df)):
    if df.at[i, 'course_number'] < 100:
        df.at[i, 'course_difficulty'] = 'below level'
    elif df.at[i, 'course_number'] < 300:
        df.at[i, 'course_difficulty'] = 'elementary'
    elif df.at[i, 'course_number'] < 500:
        df.at[i, 'course_difficulty'] = 'intermediate'
    elif df.at[i, 'course_number'] < 700:
        df.at[i, 'course_difficulty'] = 'advanced'
    elif df.at[i, 'course_number'] >= 700:
        df.at[i, 'course_difficulty'] = 'grad level'

# %%
# check
df['course_difficulty'].value_counts()
# Out:
# elementary      19932
# intermediate    18671
# grad level      17756
# advanced        11603
# below level       565
# Name: course_difficulty, dtype: int64

# %%
# we are only interested in 'elementary', 'intermediate', and 'advanced' courses
df.drop(df[(df['course_difficulty'] == 'below level') | 
           (df['course_difficulty'] == 'grad level')].index, 
        inplace = True)

# %%
# check
df['course_difficulty'].value_counts()
# Out:
# elementary      19932
# intermediate    18671
# advanced        11603
# Name: course_difficulty, dtype: int64

# %%
# drop course_number column
df.drop(columns = 'course_number', inplace = True)

# check
'course_number' in df.columns
# Out:
# False

# %% [markdown]
# # course_uuid

# %%
# can drop 'course_uuid' column because it should match up with 'course_name' column
df.drop(columns = 'course_uuid', inplace = True)

# check
'course_uuid' in df.columns
# Out:
# False

# %% [markdown]
# # 'instructor_id'
#
# The 'instructor_id' column has too many unique values to be useful for the machine learning algortihm. We will group instructors into bins based on number of courses taught.
#
# To get about 100 unique values in the column, we will bin every instructor who taught fewer classes than the top 100 instructors.

# %%
df['instructor_id'].nunique()
# Out:
# 7184

# %%
# get numbers of courses taught for top 100 instructors
df['instructor_id'].value_counts().values[:100]
# Out:
# array([137, 132, 106,  85,  81,  79,  77,  70,  69,  67,  67,  67,  66,
#         66,  64,  63,  63,  62,  61,  61,  61,  61,  60,  60,  59,  59,
#         58,  58,  58,  57,  57,  56,  55,  55,  54,  54,  54,  53,  53,
#         53,  52,  52,  52,  51,  51,  51,  50,  50,  50,  50,  49,  48,
#         48,  48,  48,  48,  47,  47,  46,  46,  46,  46,  46,  45,  45,
#         45,  45,  45,  44,  44,  44,  44,  44,  43,  43,  43,  43,  43,
#         43,  43,  43,  43,  42,  42,  42,  42,  42,  42,  41,  41,  41,
#         41,  41,  41,  40,  40,  40,  39,  39,  39], dtype=int64)

# %% [markdown]
# It looks like the top 100 instructors taught 39 or more courses each, so that is where we will choose to bin.

# %%
# create empty list to store instructor_ids of instructors who taught more
# than 38 sections
instructor_100_list = []

# iterate over values and counts in 'instructor_id'
for value, count in df['instructor_id'].value_counts().items():
  
    # if count is more than 38 (i.e. instructor taught more than 38 sections)
    if count > 38:
    
        # append to list
        instructor_100_list.append(value)

# check
len(instructor_100_list)
# Out:
# 106

# %%
# change value in 'instructor_id' column to 'other' if instructor_id is not
# on instructor_100_list 

df.loc[~df['instructor_id'].isin(instructor_100_list), 
       'instructor_id'] = 'other'

# %%
# check
df['instructor_id'].sample(10)
# Out:
# 16743    157057.0
# 3359        other
# 30671       other
# 37419       other
# 14909       other
# 61442       other
# 30572       other
# 31343       other
# 66918       other
# 45628    566960.0
# Name: instructor_id, dtype: object

# %%
# how many unique values now?
df['instructor_id'].nunique()
# Out:
# 107

# %% [markdown]
# # 'course_name'

# %% [markdown]
# As with 'instructor_id', there are too many unique values in 'course_name'.

# %%
df['course_name'].nunique()
# Out:
# 3816

# %%
# get numbers of rows for top 100 course_names
df['course_name'].value_counts().values[:100]
# Out:
# array([997, 810, 652, 491, 464, 463, 459, 418, 334, 330, 302, 300, 291,
#        252, 248, 242, 241, 231, 221, 218, 195, 185, 185, 181, 174, 155,
#        153, 151, 149, 145, 137, 136, 129, 124, 123, 119, 119, 119, 119,
#        114, 112, 111, 105, 104, 101,  99,  95,  95,  94,  93,  93,  93,
#         93,  92,  92,  92,  90,  90,  88,  87,  86,  86,  86,  85,  84,
#         84,  83,  83,  83,  83,  81,  81,  78,  77,  76,  75,  75,  75,
#         74,  73,  73,  73,  72,  72,  71,  70,  70,  69,  68,  68,  67,
#         67,  67,  65,  64,  64,  63,  63,  62,  62], dtype=int64)

# %% [markdown]
# We will bin every course_name with fewer than 62 occurrences.

# %%
# create empty list to store course_names
course_name_100_list = []

# iterate over values and counts in 'course_name'
for value, count in df['course_name'].value_counts().items():
  
    # if count is more than 61 (ie course has been taught more than 61 times)
    if count > 61:
    
        # append to list
        course_name_100_list.append(value)

# this is the number of courses that have been taught more than 61 times
print(len(course_name_100_list))
# Out:
# 103

# %%
# change 'course_name' column such that if 'course_name' is on 
# 'course_name_100_list', the course name stays, and if not, it gets changed
# to 'other'
df.loc[~df['course_name'].isin(course_name_100_list), 'course_name'] = 'other'

# %%
# check
df['course_name'].sample(10)
# Out:
# 41936               technical presentations
# 16732               technical communication
# 48257                                 other
# 18964                  freshman composition
# 25151    introductory managerial accounting
# 17867                                 other
# 43631                       weight training
# 62611                                 other
# 59102                                 other
# 40872                                 other
# Name: course_name, dtype: object

# %%
# how many unique values now in 'course_name'?
df['course_name'].nunique()
# Out:
# 104

# %% [markdown]
# # 'course_offering_name' and 'course_offering_uuid'

# %%
# course_offering_name is correlated with course_name, so we will drop 
# it for now
# course_offering_uuid will not predict grades, so we will drop it for now
df.drop(columns = ['course_offering_name', 'course_offering_uuid'], 
        inplace = True)

# %%
# check
print('course_offering_name' in df.columns)
print('course_offering_uuid' in df.columns)
# Out:
# False
# False

# %% [markdown]
# # 'section_uuid' and 'section_number'

# %%
# drop section_uuid and section_number, because they will not be predictive 
# of grades
df.drop(columns = ['section_uuid', 'section_number'], inplace = True)

# %%
# check
print('section_uuid' in df.columns)
print('section_number' in df.columns)
# Out:
# False
# False

# %% [markdown]
# # Final checks

# %%
# check unique values and value_counts() in all columns
for col in df.columns:
  print(f"{col}:")
  print(f"unique values: {df[col].nunique()}")
  print(f"value counts: \n{df[col].value_counts(dropna = False)}")
  print()
# Out:
# section_type:
# unique values: 6
# value counts:
# lec    39649
# lab     4905
# sem     2607
# ind     2182
# fld      599
# dis      264
# Name: section_type, dtype: int64
#
# instructor_id:
# unique values: 107
# value counts:
# other        44605
# 2601912.0      137
# 566960.0       132
# 496397.0       106
# 2601706.0       85
#              ...
# 631912.0        39
# 2600197.0       39
# 3659559.0       39
# 2600012.0       39
# 315329.0        39
# Name: instructor_id, Length: 107, dtype: int64
#
# facility_code:
# unique values: 120
# value counts:
# 0482     7458
# 0469     4609
# NaN      3976
# 0140     3449
# 0408     2538
#          ...
# 0092d       1
# 0039        1
# 1400k       1
# 1400g       1
# 0137        1
# Name: facility_code, Length: 121, dtype: int64
#
# start_time:
# unique values: 118
# value counts:
#  660.0    7660
#  800.0    4448
#  595.0    4372
# -1.0      4091
#  870.0    3633
#           ...
#  965.0       1
#  760.0       1
#  440.0       1
#  490.0       1
#  550.0       1
# Name: start_time, Length: 118, dtype: int64
#
# mon:
# unique values: 2
# value counts:
# False    27347
# True     22859
# Name: mon, dtype: int64
#
# tues:
# unique values: 2
# value counts:
# False    28091
# True     22115
# Name: tues, dtype: int64
#
# wed:
# unique values: 2
# value counts:
# False    27951
# True     22255
# Name: wed, dtype: int64
#
# thurs:
# unique values: 2
# value counts:
# False    29013
# True     21193
# Name: thurs, dtype: int64
#
# fri:
# unique values: 2
# value counts:
# False    37323
# True     12883
# Name: fri, dtype: int64
#
# sat:
# unique values: 2
# value counts:
# False    49967
# True       239
# Name: sat, dtype: int64
#
# sun:
# unique values: 2
# value counts:
# False    50165
# True        41
# Name: sun, dtype: int64
#
# subject_name:
# unique values: 180
# value counts:
# english                                          2975
# spanish (spanish and portuguese)                 2965
# communication arts                               1908
# art department                                   1795
# mathematics                                      1757
#                                                  ...
# human oncology                                      2
# pharmacy                                            2
# animal health and biomedical sciences               2
# agroecology                                         1
# molecular and environmental toxicology center       1
# Name: subject_name, Length: 180, dtype: int64
#
# course_name:
# unique values: 104
# value counts:
# other                                                                 34267
# introduction to speech composition                                      997
# special topics                                                          810
# freshman composition                                                    652
# directed study                                                          491
#                                                                       ...
# human resources develop: awareness processes-cnsl&guid perspective       62
# introductory ethics                                                      62
# practice i: foundations of generalist practice                           62
# beginning class piano                                                    62
# ensemble-brass                                                           62
# Name: course_name, Length: 104, dtype: int64
#
# course_and_section:
# unique values: 50206
# value counts:
# cf726c33-a4b3-3bd6-8cb9-ec403ccb72cd_37.0    1
# 2dd2eac3-26de-32cf-a963-77006f3ed8e5_3.0     1
# a176312c-6c13-3103-9e90-331a9eba5d48_2.0     1
# a176312c-6c13-3103-9e90-331a9eba5d48_3.0     1
# 5333b4f4-2706-385e-b276-950cd78a11f8_5.0     1
#                                             ..
# 87ea963f-469f-3009-9b41-8a44cc5e8da3_1.0     1
# cddb0165-2e8d-3406-883b-0a6f61e34520_1.0     1
# eed5b750-1529-3a5d-8b4d-f9b2d68a9771_1.0     1
# 195ddfcb-5e24-3bfd-ae80-364815a23cd7_1.0     1
# eac3aacc-ec57-314e-b6dd-bfa0767c72a2_1.0     1
# Name: course_and_section, Length: 50206, dtype: int64
#
# a_count:
# unique values: 230
# value counts:
# 6      3837
# 7      3505
# 8      3143
# 5      3124
# 9      2881
#        ...
# 158       1
# 236       1
# 266       1
# 216       1
# 412       1
# Name: a_count, Length: 230, dtype: int64
#
# ab_count:
# unique values: 151
# value counts:
# 0      8924
# 3      4440
# 2      4396
# 4      4216
# 1      4072
#        ...
# 123       1
# 147       1
# 107       1
# 159       1
# 183       1
# Name: ab_count, Length: 151, dtype: int64
#
# b_count:
# unique values: 160
# value counts:
# 0      14259
# 1       6225
# 2       4873
# 3       3743
# 4       3090
#        ...
# 195        1
# 167        1
# 168        1
# 203        1
# 188        1
# Name: b_count, Length: 160, dtype: int64
#
# bc_count:
# unique values: 99
# value counts:
# 0      27413
# 1       7378
# 2       4105
# 3       2279
# 4       1543
#        ...
# 97         1
# 96         1
# 90         1
# 102        1
# 84         1
# Name: bc_count, Length: 99, dtype: int64
#
# c_count:
# unique values: 109
# value counts:
# 0      30921
# 1       6815
# 2       3183
# 3       1837
# 4       1264
#        ...
# 111        1
# 157        1
# 126        1
# 129        1
# 106        1
# Name: c_count, Length: 109, dtype: int64
#
# d_count:
# unique values: 38
# value counts:
# 0     39875
# 1      4823
# 2      1897
# 3      1033
# 4       587
# 5       381
# 6       291
# 7       212
# 8       147
# 9       118
# 10      110
# 11       98
# 13       91
# 12       80
# 14       65
# 15       62
# 16       51
# 18       37
# 17       34
# 19       34
# 20       33
# 21       19
# 25       19
# 22       19
# 23       17
# 26       14
# 24       12
# 28        9
# 30        7
# 27        7
# 29        5
# 35        4
# 31        4
# 33        3
# 32        3
# 41        3
# 36        1
# 44        1
# Name: d_count, dtype: int64
#
# f_count:
# unique values: 29
# value counts:
# 0     40864
# 1      5446
# 2      1702
# 3       789
# 4       465
# 5       251
# 6       189
# 7       103
# 9        80
# 8        78
# 10       61
# 11       46
# 13       28
# 12       26
# 14       14
# 17       12
# 16       12
# 19        7
# 18        7
# 15        6
# 21        4
# 20        3
# 22        3
# 23        3
# 24        2
# 26        2
# 30        1
# 29        1
# 27        1
# Name: f_count, dtype: int64
#
# s_count:
# unique values: 85
# value counts:
# 0      43054
# 1       4132
# 2       1141
# 3        506
# 4        314
#        ...
# 51         1
# 107        1
# 163        1
# 86         1
# 62         1
# Name: s_count, Length: 85, dtype: int64
#
# u_count:
# unique values: 5
# value counts:
# 0    49914
# 1      272
# 2       18
# 3        1
# 6        1
# Name: u_count, dtype: int64
#
# cr_count:
# unique values: 12
# value counts:
# 0     49935
# 1       207
# 2        17
# 4        16
# 3         9
# 5         7
# 6         5
# 12        4
# 7         2
# 8         2
# 21        1
# 23        1
# Name: cr_count, dtype: int64
#
# n_count:
# unique values: 14
# value counts:
# 0     49817
# 1       241
# 2        81
# 3        33
# 4        13
# 5         7
# 8         5
# 10        2
# 6         2
# 7         1
# 15        1
# 9         1
# 16        1
# 13        1
# Name: n_count, dtype: int64
#
# p_count:
# unique values: 13
# value counts:
# 0     50177
# 1         7
# 2         4
# 11        3
# 9         2
# 6         2
# 10        2
# 7         2
# 8         2
# 18        2
# 3         1
# 28        1
# 19        1
# Name: p_count, dtype: int64
#
# i_count:
# unique values: 24
# value counts:
# 0     46342
# 1      3014
# 2       569
# 3       152
# 4        66
# 5        23
# 6        11
# 8         5
# 10        4
# 9         3
# 7         3
# 11        2
# 12        1
# 21        1
# 28        1
# 13        1
# 14        1
# 17        1
# 81        1
# 60        1
# 19        1
# 51        1
# 44        1
# 18        1
# Name: i_count, dtype: int64
#
# nw_count:
# unique values: 14
# value counts:
# 0     48965
# 1      1061
# 2       131
# 3        27
# 4         7
# 6         3
# 5         3
# 7         2
# 8         2
# 15        1
# 11        1
# 25        1
# 17        1
# 9         1
# Name: nw_count, dtype: int64
#
# nr_count:
# unique values: 22
# value counts:
# 0     49087
# 1       809
# 2       162
# 3        57
# 4        30
# 5        14
# 6        12
# 7        10
# 10        4
# 8         4
# 14        2
# 16        2
# 12        2
# 11        2
# 9         2
# 27        1
# 21        1
# 37        1
# 25        1
# 17        1
# 13        1
# 23        1
# Name: nr_count, dtype: int64
#
# other_count:
# unique values: 7
# value counts:
# 0    49390
# 1      753
# 2       44
# 3       10
# 4        5
# 6        2
# 5        2
# Name: other_count, dtype: int64
#
# num_all_grades:
# unique values: 461
# value counts:
# 19.0     2399
# 20.0     2012
# 13.0     1999
# 18.0     1968
# 12.0     1948
#          ...
# 420.0       1
# 415.0       1
# 476.0       1
# 412.0       1
# 606.0       1
# Name: num_all_grades, Length: 461, dtype: int64
#
# a_proportion:
# unique values: 4223
# value counts:
# 1.000000    5299
# 0.500000    1513
# 0.000000    1174
# 0.333333    1116
# 0.666667     880
#             ...
# 0.424000       1
# 0.231760       1
# 0.263566       1
# 0.364583       1
# 0.022472       1
# Name: a_proportion, Length: 4223, dtype: int64
#
# ab_proportion:
# unique values: 3561
# value counts:
# 0.000000    8924
# 0.333333    1509
# 0.250000    1311
# 0.166667    1113
# 0.200000     997
#             ...
# 0.037975       1
# 0.229299       1
# 0.292857       1
# 0.321168       1
# 0.556962       1
# Name: ab_proportion, Length: 3561, dtype: int64
#
# b_proportion:
# unique values: 3473
# value counts:
# 0.000000    14259
# 0.250000     1059
# 0.166667     1028
# 0.333333      890
# 0.200000      865
#             ...
# 0.478070        1
# 0.448430        1
# 0.248731        1
# 0.298013        1
# 0.373494        1
# Name: b_proportion, Length: 3473, dtype: int64
#
# bc_proportion:
# unique values: 2647
# value counts:
# 0.000000    27413
# 0.083333      582
# 0.090909      559
# 0.052632      557
# 0.100000      548
#             ...
# 0.094891        1
# 0.167883        1
# 0.132812        1
# 0.043165        1
# 0.213333        1
# Name: bc_proportion, Length: 2647, dtype: int64
#
# c_proportion:
# unique values: 2679
# value counts:
# 0.000000    30921
# 0.052632      465
# 0.090909      438
# 0.083333      426
# 0.050000      425
#             ...
# 0.111940        1
# 0.168539        1
# 0.178862        1
# 0.137405        1
# 0.454545        1
# Name: c_proportion, Length: 2679, dtype: int64
#
# d_proportion:
# unique values: 1654
# value counts:
# 0.000000    39875
# 0.050000      237
# 0.052632      231
# 0.045455      216
# 0.043478      209
#             ...
# 0.077465        1
# 0.041379        1
# 0.078571        1
# 0.072917        1
# 0.099057        1
# Name: d_proportion, Length: 1654, dtype: int64
#
# f_proportion:
# unique values: 1300
# value counts:
# 0.000000    40864
# 0.050000      238
# 0.052632      222
# 0.045455      212
# 0.043478      205
#             ...
# 0.038194        1
# 0.091743        1
# 0.136000        1
# 0.074627        1
# 0.013825        1
# Name: f_proportion, Length: 1300, dtype: int64
#
# s_proportion:
# unique values: 1066
# value counts:
# 0.000000    43054
# 1.000000      196
# 0.052632      180
# 0.055556      166
# 0.050000      164
#             ...
# 0.114943        1
# 0.058140        1
# 0.060976        1
# 0.068493        1
# 0.962025        1
# Name: s_proportion, Length: 1066, dtype: int64
#
# u_proportion:
# unique values: 152
# value counts:
# 0.000000    49914
# 0.142857       13
# 0.071429       10
# 0.047619       10
# 0.052632        9
#             ...
# 0.011236        1
# 0.023810        1
# 0.021277        1
# 0.017857        1
# 0.005263        1
# Name: u_proportion, Length: 152, dtype: int64
#
# cr_proportion:
# unique values: 30
# value counts:
# 0.000000    49935
# 0.500000      129
# 0.333333       63
# 0.250000       12
# 0.800000        7
# 0.200000        7
# 0.857143        6
# 0.750000        6
# 0.666667        6
# 0.714286        4
# 0.142857        4
# 1.000000        3
# 0.571429        3
# 0.400000        3
# 0.444444        2
# 0.428571        2
# 0.875000        1
# 0.083333        1
# 0.187500        1
# 0.190476        1
# 0.285714        1
# 0.111111        1
# 0.777778        1
# 0.416667        1
# 0.238095        1
# 0.363636        1
# 0.090909        1
# 0.166667        1
# 0.700000        1
# 0.884615        1
# Name: cr_proportion, dtype: int64
#
# n_proportion:
# unique values: 34
# value counts:
# 0.000000    49817
# 0.500000      132
# 1.000000      125
# 0.666667       64
# 0.333333       10
# 0.800000        8
# 0.750000        7
# 0.071429        4
# 0.714286        3
# 0.142857        3
# 0.250000        3
# 0.200000        3
# 0.100000        2
# 0.285714        2
# 0.833333        2
# 0.600000        2
# 0.571429        2
# 0.555556        1
# 0.761905        1
# 0.041667        1
# 0.533333        1
# 0.625000        1
# 0.812500        1
# 0.444444        1
# 0.909091        1
# 0.642857        1
# 0.857143        1
# 0.428571        1
# 0.111111        1
# 0.636364        1
# 0.888889        1
# 0.125000        1
# 0.222222        1
# 0.038462        1
# Name: n_proportion, dtype: int64
#
# p_proportion:
# unique values: 11
# value counts:
# 0.000000    50177
# 1.000000       16
# 0.166667        3
# 0.083333        2
# 0.285714        2
# 0.100000        1
# 0.333333        1
# 0.428571        1
# 0.142857        1
# 0.048780        1
# 0.250000        1
# Name: p_proportion, dtype: int64
#
# i_proportion:
# unique values: 554
# value counts:
# 0.000000    46342
# 0.052632      111
# 0.083333       98
# 0.076923       98
# 0.066667       97
#             ...
# 0.030769        1
# 0.027624        1
# 0.006098        1
# 0.012308        1
# 0.037975        1
# Name: i_proportion, Length: 554, dtype: int64
#
# nw_proportion:
# unique values: 343
# value counts:
# 0.000000    48965
# 0.043478       34
# 0.062500       29
# 0.047619       28
# 0.055556       27
#             ...
# 0.002445        1
# 0.002024        1
# 0.009950        1
# 0.002398        1
# 0.057554        1
# Name: nw_proportion, Length: 343, dtype: int64
#
# nr_proportion:
# unique values: 364
# value counts:
# 0.000000    49087
# 0.058824       26
# 0.052632       24
# 0.045455       23
# 0.142857       23
#             ...
# 0.008850        1
# 0.028986        1
# 0.004890        1
# 0.002488        1
# 0.004975        1
# Name: nr_proportion, Length: 364, dtype: int64
#
# other_proportion:
# unique values: 289
# value counts:
# 0.000000    49390
# 0.058824       25
# 0.052632       25
# 0.055556       24
# 0.062500       21
#             ...
# 0.002950        1
# 0.002899        1
# 0.002786        1
# 0.004386        1
# 0.010050        1
# Name: other_proportion, Length: 289, dtype: int64
#
# avg_letter_grade:
# unique values: 6955
# value counts:
# 4.000000    6040
# 3.500000    1278
# 3.750000     789
# NaN          715
# 3.833333     553
#             ...
# 3.638075       1
# 3.480565       1
# 2.840206       1
# 3.819767       1
# 3.210227       1
# Name: avg_letter_grade, Length: 6956, dtype: int64
#
# year:
# unique values: 12
# value counts:
# 07    4784
# 08    4623
# 11    4602
# 10    4586
# 09    4586
# 14    4568
# 13    4534
# 15    4502
# 16    4451
# 17    4371
# 12    2327
# 18    2272
# Name: year, dtype: int64
#
# term:
# unique values: 2
# value counts:
# fall      28141
# spring    22065
# Name: term, dtype: int64
#
# class_length:
# unique values: 62
# value counts:
# 50.0     19683
# 75.0     15449
# 0.0       4091
# 150.0     3384
# 120.0     2061
#          ...
# 190.0        3
# 200.0        2
# 113.0        1
# 40.0         1
# 520.0        1
# Name: class_length, Length: 62, dtype: int64
#
# course_difficulty:
# unique values: 3
# value counts:
# elementary      19932
# intermediate    18671
# advanced        11603
# Name: course_difficulty, dtype: int64

# %%
# check length of df
len(df)
# Out:
# 50206

# %%
# 'course_and_section' is uniquely identifying each row, so it can be dropped
df.drop(columns = 'course_and_section', inplace = True)

# check
'course_and_section' in df.columns
# Out:
# False

# %%
# reset index
df.reset_index(drop = True, inplace = True)

# check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50206 entries, 0 to 50205
# Data columns (total 51 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   section_type       50206 non-null  object
#  1   instructor_id      50206 non-null  object
#  2   facility_code      46230 non-null  object
#  3   start_time         50206 non-null  float64
#  4   mon                50206 non-null  bool
#  5   tues               50206 non-null  bool
#  6   wed                50206 non-null  bool
#  7   thurs              50206 non-null  bool
#  8   fri                50206 non-null  bool
#  9   sat                50206 non-null  bool
#  10  sun                50206 non-null  bool
#  11  subject_name       50206 non-null  object
#  12  course_name        50206 non-null  object
#  13  a_count            50206 non-null  int64
#  14  ab_count           50206 non-null  int64
#  15  b_count            50206 non-null  int64
#  16  bc_count           50206 non-null  int64
#  17  c_count            50206 non-null  int64
#  18  d_count            50206 non-null  int64
#  19  f_count            50206 non-null  int64
#  20  s_count            50206 non-null  int64
#  21  u_count            50206 non-null  int64
#  22  cr_count           50206 non-null  int64
#  23  n_count            50206 non-null  int64
#  24  p_count            50206 non-null  int64
#  25  i_count            50206 non-null  int64
#  26  nw_count           50206 non-null  int64
#  27  nr_count           50206 non-null  int64
#  28  other_count        50206 non-null  int64
#  29  num_all_grades     50206 non-null  float64
#  30  a_proportion       50206 non-null  float64
#  31  ab_proportion      50206 non-null  float64
#  32  b_proportion       50206 non-null  float64
#  33  bc_proportion      50206 non-null  float64
#  34  c_proportion       50206 non-null  float64
#  35  d_proportion       50206 non-null  float64
#  36  f_proportion       50206 non-null  float64
#  37  s_proportion       50206 non-null  float64
#  38  u_proportion       50206 non-null  float64
#  39  cr_proportion      50206 non-null  float64
#  40  n_proportion       50206 non-null  float64
#  41  p_proportion       50206 non-null  float64
#  42  i_proportion       50206 non-null  float64
#  43  nw_proportion      50206 non-null  float64
#  44  nr_proportion      50206 non-null  float64
#  45  other_proportion   50206 non-null  float64
#  46  avg_letter_grade   49491 non-null  float64
#  47  year               50206 non-null  object
#  48  term               50206 non-null  object
#  49  class_length       50206 non-null  float64
#  50  course_difficulty  50206 non-null  object
# dtypes: bool(7), float64(20), int64(16), object(8)
# memory usage: 17.2+ MB

# %%
# inspect
df.sample(10)
# Out:
#       section_type instructor_id facility_code  start_time    mon   tues  \
# 1238           lec         other    off campus        -1.0  False  False
# 45974          lec         other          0482       800.0   True   True
# 42994          lec         other          0482       725.0   True   True
# 31671          lec      980056.0          0481       660.0   True  False
# 19908          lec         other          0140       865.0  False  False
# 15943          lec         other          0482       800.0   True  False
# 9708           fld         other          1480       480.0   True  False
# 17075          sem         other          0046       960.0  False   True
# 4106           lec         other          0407       870.0  False   True
# 29868          lec         other          0046       570.0  False   True
#
#          wed  thurs    fri    sat  ...  p_proportion i_proportion  \
# 1238   False  False  False  False  ...           0.0     0.000000
# 45974   True   True  False  False  ...           0.0     0.000000
# 42994   True   True  False  False  ...           0.0     0.000000
# 31671   True  False  False  False  ...           0.0     0.000000
# 19908   True  False  False  False  ...           0.0     0.000000
# 15943   True  False   True  False  ...           0.0     0.000000
# 9708   False  False  False  False  ...           0.0     0.000000
# 17075  False   True  False  False  ...           0.0     0.042553
# 4106   False   True  False  False  ...           0.0     0.000000
# 29868  False   True  False  False  ...           0.0     0.000000
#
#       nw_proportion  nr_proportion  other_proportion  avg_letter_grade  year  \
# 1238       0.000000            0.0          0.000000          3.933333    14
# 45974      0.000000            0.0          0.000000          3.500000    07
# 42994      0.000000            0.0          0.083333          3.136364    12
# 31671      0.000000            0.0          0.000000          3.315789    13
# 19908      0.000000            0.0          0.000000          3.875000    07
# 15943      0.000000            0.0          0.000000          3.652174    09
# 9708       0.000000            0.0          0.000000          3.925676    14
# 17075      0.021277            0.0          0.000000          3.284091    17
# 4106       0.000000            0.0          0.000000          3.604167    13
# 29868      0.000000            0.0          0.000000          3.388889    07
#
#          term  class_length  course_difficulty
# 1238   spring           0.0         elementary
# 45974    fall          50.0         elementary
# 42994    fall          50.0         elementary
# 31671    fall          50.0         elementary
# 19908  spring         155.0       intermediate
# 15943    fall          50.0       intermediate
# 9708   spring          50.0       intermediate
# 17075  spring          75.0       intermediate
# 4106   spring          75.0       intermediate
# 29868  spring          75.0       intermediate
#
# [10 rows x 51 columns]

# %% [markdown]
# # Final data dictionary
#
# - section_type: such as lecture, discussion, field, etc.
# - instructor_id: instructor
# - facility_code: building
# - start_time: start time of class in minutes (-1: no start time assigned)
# - mon, tues, wed, thurs, fri, sat, sun: if class meets on that day
# - subject_name: subject
# - year: academic year (calendar year of spring term)
# - term: fall or spring
# - course_name: same for same course across terms
# - course_difficulty: based on course numbering system
# - class_length: number of minutes between start and end time
# - num_all_grades: number of all grades, letter or other, given in section
# - count and proportion columns each for following grades: a, ab, b, bc, c, d, f, s, u, cr, n, p, i, nw, nr, other
# - avg_letter_grade: average grade on 4.0 scale counting all letter grades awarded

# %% [markdown]
# # Check for (and delete) duplicates

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 231

# %%
# drop
df.drop_duplicates(inplace = True)

# %%
# check again
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Identify and address missing values

# %%
df.isna().sum()
# Out:
# section_type            0
# instructor_id           0
# facility_code        3491
# start_time              0
# mon                     0
# tues                    0
# wed                     0
# thurs                   0
# fri                     0
# subject_name            0
# course_name             0
# a_proportion            0
# f_proportion            0
# avg_grade               0
# year                    0
# term                    0
# class_length            0
# total_time              0
# weekend                 0
# course_difficulty       0
# dtype: int64

# %% [markdown]
# The only column missing values is 'facility_code'. This is the column that gives the building where the section was held. Missing values here could mean that the section was never assigned a classroom (i.e., that it was up to the instructor and students to arrange their own meeting place).
#
# In machine learning preprocessing, we will impute these missing values with the constant 'missing'.

# %% [markdown]
# # Identify and correct inconsistencies in categorical values

# %%
df.dtypes
# Out:
# section_type          object
# instructor_id         object
# facility_code         object
# start_time           float64
# mon                   object
# tues                  object
# wed                   object
# thurs                 object
# fri                   object
# subject_name          object
# course_name           object
# a_proportion         float64
# f_proportion         float64
# avg_grade            float64
# year                  object
# term                  object
# class_length         float64
# total_time             int64
# weekend               object
# course_difficulty     object
# dtype: object

# %%
# check values in 'object' columns
dtypes = df.dtypes
object_dtypes = dtypes[dtypes == 'object']

for column in object_dtypes.index:
    print(column)
    print(df[column].unique())
    print()
# Out:
# section_type
# ['lec' 'ind' 'sem' 'lab' 'fld' 'dis']
#
# instructor_id
# ['other' 2601642.0 309711.0 811223.0 2602070.0 886751.0 3659559.0 685141.0
#  2600075.0 1112569.0 566960.0 3234517.0 377240.0 631912.0 3013497.0
#  663146.0 464468.0 623858.0 965150.0 2601467.0 342827.0 2601912.0 984470.0
#  964473.0 809212.0 777651.0 960897.0 4530799.0 3128595.0 344599.0 260106.0
#  4232086.0 2601573.0 3357721.0 2600197.0 900201.0 1005245.0 412406.0
#  4232087.0 922322.0 3382514.0 710039.0 783847.0 2600759.0 2601502.0
#  496397.0 3793122.0 2601181.0 3673656.0 2600559.0 3615604.0 2600403.0
#  423731.0 718608.0 819732.0 157057.0 2601527.0 650044.0 130429.0 1005574.0
#  446645.0 573481.0 133526.0 692771.0 2601066.0 636841.0 3076440.0
#  5476239.0 685944.0 4841799.0 1600563.0 3029337.0 980056.0 2600282.0
#  315329.0 3105692.0 2600807.0 818841.0 806537.0 4124270.0 2601630.0
#  3041045.0 2601318.0 710873.0 2600598.0 4539921.0 470031.0 3383097.0
#  4083699.0 593987.0 565790.0 2602098.0 3216300.0 2601320.0 302280.0
#  159304.0 2601242.0 2601706.0 3011973.0 319547.0 921047.0 697108.0
#  526677.0 3013999.0 807999.0 2600012.0 1663711.0]
#
# facility_code
# [nan '0545' '1245' '1246' '0567' '0154' '0469' '0400' '0574c' '1245c'
#  '1246c' '1243' '0140' '0560' '0056' '0054' '0050' '0470' '0408' '0046'
#  '0048' '0084' '0047' '0055' '0057' '0482' '0070' 'online' 'off campus'
#  '0074b' '0087c' '0506' '0053' '0080' '0129' '0544' '1079' '0407' '0449'
#  '0114' '0485' '0085' '0118' '0031' '1480' '0155' '0044' '1400' '0402'
#  '0404' '0481' '0557' '0153' '0032' '0106' '0060' '0087a' '0450' '0137'
#  '0453' '0078' '0082' '0102' '0018' '0083' '0076' '0115' '0110' '0052'
#  '0430' '0576' '0452' '0220' '0084b' '0034' '1400e' '1405e' '0035' '1405g'
#  '0520' '0093' '0486' '1485' '0762' '1400g' '0039' '0451c' '0451b' '0468'
#  '0011' '0451a' '0521' '1406k' '0205' '0204' '0508' '0479' '0033' '0156'
#  '1247c' '0000' '0021' '0099' '0464' '0015' '0025' '1404k' '0403' '0503'
#  '1095' '0505' '0103' '0028' '0038' '0782' '0507' '0092d' '0123' '1400k'
#  '0116' '0476']
#
# subject_name
# ['communication arts' 'atmospheric and oceanic sciences' 'history'
#  'international studies' 'physics' 'sociology' 'nutritional sciences'
#  'music-performance' 'music' 'engineering professional development'
#  'interdisciplinary courses (cals)' 'integrated liberal studies'
#  'theatre and drama' 'journalism and mass communication' 'english'
#  'geography' 'naval science' 'art history'
#  'electrical and computer engineering' 'nursing' 'mathematics' 'dance'
#  'landscape architecture' 'interdisciplinary courses (l&s)' 'horticulture'
#  'biological systems engineering' 'scandinavian studies'
#  'consumer science' 'literature in translation' 'biochemistry'
#  'mechanical engineering' 'microbiology' 'food science' 'dairy science'
#  'east asian languages and literature' 'agronomy'
#  'forest and wildlife ecology' 'zoology' 'entomology'
#  'interdisciplinary courses (sohe)' 'genetics' 'chemistry'
#  'community and environmental sociology' 'plant pathology'
#  'italian (french and italian)'
#  'rehabilitation psychology and special education'
#  'accounting and information systems' 'languages and cultures of asia'
#  'management and human resources' 'kinesiology' 'general business'
#  'interdisciplinary courses (engineering)' 'east asian area studies'
#  'pharmacy practice' 'collaborative nursing program'
#  'languages and cultures of asia - languages' 'computer sciences'
#  'psychology' 'biomedical engineering' 'botany' 'geoscience'
#  'political science' 'human development and family studies'
#  'finance, investment and banking' 'information systems'
#  'real estate and urban land economics' 'african languages and literature'
#  'curriculum and instruction' 'biology'
#  'agricultural and applied economics' 'life sciences communication'
#  'animal sciences' 'german' 'marketing' 'religious studies'
#  'geological engineering'
#  'environmental studies - gaylord nelson institute'
#  'industrial and systems engineering'
#  'civil and environmental engineering' 'art department'
#  'library and information studies' 'astronomy' 'engineering physics'
#  'educational leadership and policy analysis' 'population health sciences'
#  'educational psychology' 'pharmaceutical sciences'
#  'chemical and biological engineering'
#  'medical sciences - veterinary medicine' 'social work'
#  'engineering mechanics and astronautics' 'educational policy studies'
#  'nuclear engineering' 'counseling psychology'
#  'physician assistant program' 'design studies' 'physical therapy'
#  'surgical sciences' 'medical physics' 'physiology' 'oncology'
#  'patho-biological sciences' 'medical microbiology and immunology'
#  'anthropology' 'soil science' 'medicine'
#  'spanish (spanish and portuguese)' 'biomolecular chemistry'
#  'human oncology' 'slavic (slavic languages)' 'family medicine'
#  'communication sciences and disorders' 'legal studies'
#  'comparative biosciences' 'psychiatry' 'surgery' 'comparative literature'
#  'american indian studies' 'anatomy' 'ophthalmology and visual sciences'
#  'pathology and laboratory medicine' 'pediatrics' 'neurology'
#  'obstetrics and gynecology' 'neurological surgery' 'neuroscience'
#  'neuroscience training program' 'gender and women’s studies'
#  'biology core curriculum' 'biostatistics and medical informatics'
#  'history of science' 'social and administrative pharmacy'
#  'cell and regenerative biology' 'medical genetics'
#  'medical sciences - medical school' 'afro-american studies'
#  'chicana/o and latina/o studies' 'linguistics'
#  'molecular and environmental toxicology center'
#  'operations and technology management'
#  'latin american, caribbean, and iberian studies' 'international business'
#  'jewish studies' 'agroecology' 'civil society and community studies'
#  'folklore program' 'wildlife ecology' 'materials science and engineering'
#  'integrated science' 'classics' 'french (french and italian)'
#  'philosophy' 'economics' 'statistics' 'asian american studies'
#  'greek (classics)' 'hebrew' 'portuguese (spanish and portuguese)'
#  'science and technology studies' 'risk management and insurance'
#  'actuarial science' 'latin (classics)' 'medical history and bioethics'
#  'physical educ activity progm' 'urban and regional planning'
#  'english as a second language' 'farm & industry short course'
#  'clinical laboratory science' 'air force aerospace studies'
#  'medieval studies' 'occupational therapy (department of kinesiology)'
#  'military science' 'therapeutic science (department of kinesiology)'
#  'professional orientation' 'molecular biology' 'hebrew-modern' 'law'
#  'art education (department of art)' 'pharmacy'
#  'animal health and biomedical sciences']
#
# course_name
# ['introduction to speech composition' 'other' 'nutrition today'
#  'directed study' 'calculus and analytic geometry 1'
#  'calculus and analytic geometry 2' 'ensemble-brass' 'independent study'
#  'directed studies in zoology' 'managing organizations'
#  'contemporary topics' 'special topics'
#  'selected topics in political science'
#  'special topics: social perspectives in environmental studies'
#  'current topics in psychology' 'topics in sociology' 'special problems'
#  'special topics in theatre and drama' 'mentored research and seminar'
#  'general seminar'
#  'special topics in engineering professional development'
#  'advanced independent study' 'undergraduate seminar'
#  'technical communication' 'introduction to art'
#  'introduction to programming' 'introduction to college composition'
#  'intermediate composition' 'freshman composition'
#  'introduction to philosophy' 'introductory ethics'
#  'contemporary moral issues' 'algebra' 'analysis i'
#  'intermediate language practice with emphasis on writing and grammar'
#  'advanced language practice' 'advanced conversation'
#  'classical sociological theory'
#  'linear algebra and differential equations' 'spanish phonetics'
#  'introductory applied statistics for the life sciences'
#  'introduction to literary analysis'
#  'introduction to hispanic literatures'
#  'human resources development: educational effectiveness'
#  'consumer behavior' 'introductory financial accounting'
#  'introductory managerial accounting' 'financial reporting i'
#  'professional communication' 'trigonometry' 'corporation finance'
#  'introduction to statistical methods'
#  'calculus--functions of several variables'
#  'intermediate language and culture' 'general chemistry i'
#  'general chemistry ii' 'basic statistics for psychology'
#  'research methods' 'intermediate organic chemistry'
#  'introduction to acting' 'esl:academc readng&vocablry'
#  'esl: academic writing i' 'esl: academic writing ii'
#  'academic writing ii' 'elementary latin' 'introductory organic chemistry'
#  'basic communication' 'public speaking' 'technical presentations'
#  'engineering design projects' 'weight training'
#  'human resources develop: awareness processes-cnsl&guid perspective'
#  'human resources development: career strategies'
#  'a wisconsin experience seminar' 'intermediate fiction wrkshp'
#  'advanced seminar in history' 'field practice and integrative seminar i'
#  'field practice and integrative seminar ii'
#  'biology of microorganisms laboratory' 'fourth semester spanish'
#  'first semester german' 'second semester german'
#  'second semester spanish' 'first semester spanish'
#  'second semester italian' 'first semester italian'
#  'second semester french' 'first semester french'
#  'creatv writng:beg fict&poet' 'third semester french'
#  'fourth semester french' 'third semester german'
#  'principles and practices of reporting' 'two-dimensional design'
#  'three-dimensional design' 'introduction to digital forms' 'drawing i'
#  'drawing methods & concepts' 'fourth semester german'
#  'third semester italian' 'practice i: foundations of generalist practice'
#  'beginning class piano' 'general microbiology laboratory'
#  'third semester spanish']
#
# year
# ['15' '13' '18' '14' '11' '10' '16' '17' '07' '08' '09' '12']
#
# term
# ['spring' 'fall']
#
# course_difficulty
# ['elementary' 'intermediate' 'advanced']

# %%
# check values in numeric columns
df.describe(include = 'number')
# Out:
#          start_time       a_count      ab_count       b_count      bc_count  \
# count  49975.000000  49975.000000  49975.000000  49975.000000  49975.000000
# mean     672.910255     14.499790      8.032436      7.410965      2.744292
# std      245.748156     20.346604     13.114430     14.649307      6.937000
# min       -1.000000      0.000000      0.000000      0.000000      0.000000
# 25%      570.000000      6.000000      1.000000      0.000000      0.000000
# 50%      660.000000      9.000000      4.000000      2.000000      0.000000
# 75%      865.000000     16.000000      9.000000      7.000000      2.000000
# max     1260.000000    694.000000    234.000000    219.000000    125.000000
#
#             c_count       d_count       f_count       s_count       u_count  \
# count  49975.000000  49975.000000  49975.000000  49975.000000  49975.000000
# mean       2.473037      0.695488      0.414787      0.540750      0.006343
# std        7.614905      2.425147      1.373987      3.910638      0.087999
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      0.000000      0.000000      0.000000      0.000000
# max      157.000000     44.000000     30.000000    165.000000      6.000000
#
#        ...  u_proportion  cr_proportion  n_proportion  p_proportion  \
# count  ...  49975.000000   49975.000000  49975.000000  49975.000000
# mean   ...      0.000210       0.002403      0.005138      0.000371
# std    ...      0.003887       0.035476      0.063172      0.018250
# min    ...      0.000000       0.000000      0.000000      0.000000
# 25%    ...      0.000000       0.000000      0.000000      0.000000
# 50%    ...      0.000000       0.000000      0.000000      0.000000
# 75%    ...      0.000000       0.000000      0.000000      0.000000
# max    ...      0.142857       1.000000      1.000000      1.000000
#
#        i_proportion  nw_proportion  nr_proportion  other_proportion  \
# count  49975.000000   49975.000000   49975.000000      49975.000000
# mean       0.004748       0.001013       0.001491          0.000642
# std        0.027221       0.011966       0.021864          0.010205
# min        0.000000       0.000000       0.000000          0.000000
# 25%        0.000000       0.000000       0.000000          0.000000
# 50%        0.000000       0.000000       0.000000          0.000000
# 75%        0.000000       0.000000       0.000000          0.000000
# max        1.000000       1.000000       1.000000          1.000000
#
#        avg_letter_grade  class_length
# count      49286.000000  49975.000000
# mean           3.517272     74.013607
# std            0.375103     50.271292
# min            0.000000      0.000000
# 25%            3.266667     50.000000
# 50%            3.562500     75.000000
# 75%            3.833333     75.000000
# max            4.000000    600.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# These values look reasonable.
#
# - 'start_time':
#   - Values of -1 mean that there is no assigned start time for the course.
#   - The max start time is 1260 minutes, which is 9pm.
#
# - The proportion columns are between 0 and 1.
#
# - 'avg_letter_grade' is between 0 and 4.
#
# - 'class_length' and 'total_time':
#   - The min values are 0, which represent courses that were not assigned a meeting time/schedule.
#   - The max values are interesting. A 'class_length' value of 600 minutes (10 hours) is unusual. College courses rarely (if ever) meet for 10 hours per week, much less 10 hours at a time.

# %%
df[df['class_length'] == 600]
# Out:
#       section_type instructor_id facility_code  start_time    mon   tues  \
# 8387           sem         other           NaN       480.0  False  False
# 9055           fld      685944.0    off campus       420.0   True   True
# 9056           fld      685944.0    off campus       420.0   True   True
# 9057           fld      685944.0    off campus       420.0   True   True
# 45792          fld         other    off campus       480.0   True   True
# 45793          fld         other    off campus       480.0   True   True
# 48081          fld      685944.0    off campus       420.0   True   True
# 48082          fld      685944.0    off campus       420.0   True   True
# 48091          fld      685944.0    off campus       420.0   True   True
# 48092          fld      685944.0    off campus       420.0   True   True
#
#         wed  thurs    fri    sat  ...  p_proportion i_proportion  \
# 8387   True  False  False  False  ...           0.0          0.0
# 9055   True   True   True  False  ...           0.0          0.0
# 9056   True   True   True  False  ...           0.0          0.0
# 9057   True   True   True  False  ...           0.0          0.0
# 45792  True   True   True  False  ...           0.0          0.0
# 45793  True   True   True  False  ...           0.0          0.0
# 48081  True   True   True  False  ...           0.0          0.0
# 48082  True   True   True  False  ...           0.0          0.0
# 48091  True   True   True  False  ...           0.0          0.0
# 48092  True   True   True  False  ...           0.0          0.0
#
#       nw_proportion  nr_proportion  other_proportion  avg_letter_grade  year  \
# 8387            0.0            0.0               0.0          4.000000    11
# 9055            0.0            0.0               0.0          3.937500    10
# 9056            0.0            0.0               0.0          3.892857    11
# 9057            0.0            0.0               0.0          3.772727    11
# 45792           0.0            0.0               0.0          4.000000    17
# 45793           0.0            0.0               0.0          4.000000    16
# 48081           0.0            0.0               0.0          3.964286    10
# 48082           0.0            0.0               0.0          3.875000    11
# 48091           0.0            0.0               0.0          3.916667    10
# 48092           0.0            0.0               0.0          3.958333    11
#
#          term  class_length  course_difficulty
# 8387   spring         600.0           advanced
# 9055     fall         600.0           advanced
# 9056     fall         600.0           advanced
# 9057     fall         600.0           advanced
# 45792  spring         600.0           advanced
# 45793  spring         600.0           advanced
# 48081    fall         600.0           advanced
# 48082    fall         600.0           advanced
# 48091    fall         600.0           advanced
# 48092    fall         600.0           advanced
#
# [10 rows x 51 columns]

# %% [markdown]
# It looks like all of the courses with 600 minutes as their 'class_length' are all at the advanced level and are all but one field classes. Based on their course names, I expect these are internship-like courses, where the student is expected to block off the entire workweek for the course and intern in an off-campus location for credit. This seems plausible, so I will keep these values.
#
# The course that isn't a field course is the seminar in international studies that meets for 600 minutes on one day of the week. This seems very unusual, but without any more information about it, I will keep it.

# %% [markdown]
# # Export to csv

# %%
df.to_csv('Data/all_grades_data_cleaned.csv')
