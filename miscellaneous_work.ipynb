# %% [markdown]
# # Miscellaneous Work

# %% [markdown]
# # Ideas to add

# %% [markdown]
# 1. Further cleaning:
#     - make days of the week variables into one categorical column with values
#     - like MW, TR, MWF, etc.
#     - get back number of students (= grades) per class
#     - combine course and subject names into departments
#
#
# 2. Plot ideas
#     - are course difficulties split evenly between fall and spring semesters? #amro's idea
#     - good way to visualize 'instructor_id', 'course_name', 'subject_name', 'facility_code'?
#         - 'facility_code' = map of campus with key for facility_code numbers?
#         - subject_name = would probably have to group into departments, then could visualize with circle sizes; same with course_name

# %% [markdown]
# # Parallel Work

# %%
# import libraries

import warnings
warnings.filterwarnings('ignore')

# general
import numpy as np
import pandas as pd

# preprocessing
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split

# modeling
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, \
GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# evaluation
from sklearn.metrics import r2_score, mean_absolute_error, \
mean_squared_error, mean_absolute_percentage_error

# tuning
from sklearn.model_selection import GridSearchCV

# feature engineering
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn import set_config
set_config(display="text")
from kneed import KneeLocator

# %%
# load data
path = 'Data/all_grades_data_cleaned.csv'
df = pd.read_csv(path, index_col = 0)

# %%
df_fe = df.copy()

# %% [markdown]
# ## 'num_all_grades'

# %%
# see description of column
df_fe['num_all_grades'].describe()
# Out:
# count    49975.000000
# mean        37.047684
# std         52.705481
# min          1.000000
# 25%         13.000000
# 50%         20.000000
# 75%         35.000000
# max        712.000000
# Name: num_all_grades, dtype: float64

# %%
# small = under 15
# medium = 16-35
# large = over 35

# bin 
for index in df_fe['num_all_grades'].index:
    if df_fe.at[index, 'num_all_grades'] < 16:
        df_fe.at[index, 'num_all_grades'] = 'small'
    elif df_fe.at[index, 'num_all_grades'] < 36:
        df_fe.at[index, 'num_all_grades'] = 'medium'
    else:
        df_fe.at[index, 'num_all_grades'] = 'large'
      
# check
df_fe['num_all_grades'].value_counts()
# Out:
# medium    20701
# small     17024
# large     12250
# Name: num_all_grades, dtype: int64

# %% [markdown]
# # Correlations

# %%
## Correlation heatmap

# to visualize correlations in a heatmap with categorical variables, they need
# to be converted to numbers; will use get_dummies to convert categorical
# columns to dummy columns that are binary encoded

# make a copy of df
df_corr = df.copy()

# %%
df.columns

# %%
# can binary encode days of week and weekend without using get_dummies
days_cols = ['mon', 'tues', 'wed', 'thurs', 'fri', 'weekend']

for col in days_cols:
  df_corr[col].replace({True: 1, False: 0, 'True': 1, 'False': 0}, 
                       inplace = True)
  # check
  print(df_corr[col].value_counts())

# %%
cat_cols = ['section_type', 'instructor_id', 'facility_code','subject_name', 
            'course_name', 'year', 'term', 'course_difficulty']

for col in cat_cols:

  # use get_dummies to create dummy variables for columns
  # example: dummy_cols = pd.get_dummies(df['col'], prefix = 'category')
  dummy_cols = pd.get_dummies(df_corr[col], prefix = str(col))

  # concatenate the dummy variables with the original df
  # example: df = pd.concat([df, dummy_cols], axis = 1)
  df_corr = pd.concat([df_corr, dummy_cols], axis = 1)

  # drop original categorical variable
  # example: df.drop(columns = 'col', inplace = True)
  df_corr.drop(columns = col, inplace = True)

# check
df_corr.info()

# %%
# make the correlations
corr = df_corr.corr()

# %%
# check
corr
# Out:
#                                 start_time       mon      tues       wed  \
# start_time                        1.000000  0.158021  0.159183  0.162163
# mon                               0.158021  1.000000 -0.499735  0.771070
# tues                              0.159183 -0.499735  1.000000 -0.550931
# wed                               0.162163  0.771070 -0.550931  1.000000
# thurs                             0.147013 -0.465654  0.829200 -0.518327
# ...                                    ...       ...       ...       ...
# term_fall                         0.020453  0.028300  0.012340  0.019367
# term_spring                      -0.020453 -0.028300 -0.012340 -0.019367
# course_difficulty_advanced       -0.134619 -0.187294 -0.079132 -0.160753
# course_difficulty_elementary      0.058485  0.231860  0.050282  0.182533
# course_difficulty_intermediate    0.056868 -0.072834  0.017370 -0.045882
#
#                                    thurs       fri  a_proportion  \
# start_time                      0.147013  0.001553     -0.140318
# mon                            -0.465654  0.532388     -0.217519
# tues                            0.829200 -0.322488     -0.123339
# wed                            -0.518327  0.464109     -0.168055
# thurs                           1.000000 -0.308618     -0.148295
# ...                                  ...       ...           ...
# term_fall                       0.007909  0.028962     -0.038409
# term_spring                    -0.007909 -0.028962      0.038409
# course_difficulty_advanced     -0.091602 -0.133932      0.204297
# course_difficulty_elementary    0.066410  0.211775     -0.145207
# course_difficulty_intermediate  0.011824 -0.098504     -0.029302
#
#                                 f_proportion  avg_grade  class_length  ...  \
# start_time                          0.022375  -0.101099      0.426577  ...
# mon                                 0.059189  -0.207958     -0.115468  ...
# tues                                0.011615  -0.098378      0.092673  ...
# wed                                 0.054870  -0.165456     -0.089760  ...
# thurs                               0.019003  -0.123148      0.070654  ...
# ...                                      ...        ...           ...  ...
# term_fall                           0.001864  -0.022418     -0.002830  ...
# term_spring                        -0.001864   0.022418      0.002830  ...
# course_difficulty_advanced         -0.069988   0.202528      0.071621  ...
# course_difficulty_elementary        0.083230  -0.153810     -0.156272  ...
# course_difficulty_intermediate     -0.023772  -0.019092      0.096118  ...
#
#                                  year_14   year_15   year_16   year_17  \
# start_time                      0.003184  0.000212 -0.001043 -0.000297
# mon                            -0.007911 -0.012212 -0.012997 -0.017070
# tues                           -0.000573 -0.002351 -0.009695 -0.012293
# wed                            -0.006301 -0.012136 -0.007551 -0.006927
# thurs                          -0.000807 -0.000278 -0.010577 -0.014155
# ...                                  ...       ...       ...       ...
# term_fall                      -0.026459 -0.024630 -0.026089 -0.030456
# term_spring                     0.026459  0.024630  0.026089  0.030456
# course_difficulty_advanced      0.002118 -0.000280  0.003900  0.002816
# course_difficulty_elementary   -0.008151 -0.010224 -0.019835 -0.015036
# course_difficulty_intermediate  0.006406  0.010564  0.016669  0.012757
#
#                                  year_18  term_fall  term_spring  \
# start_time                     -0.002680   0.020453    -0.020453
# mon                            -0.009197   0.028300    -0.028300
# tues                           -0.010329   0.012340    -0.012340
# wed                            -0.002904   0.019367    -0.019367
# thurs                          -0.016916   0.007909    -0.007909
# ...                                  ...        ...          ...
# term_fall                       0.191775   1.000000    -1.000000
# term_spring                    -0.191775  -1.000000     1.000000
# course_difficulty_advanced     -0.006320  -0.034414     0.034414
# course_difficulty_elementary    0.008248   0.048725    -0.048725
# course_difficulty_intermediate -0.002886  -0.019564     0.019564
#
#                                 course_difficulty_advanced  \
# start_time                                       -0.134619
# mon                                              -0.187294
# tues                                             -0.079132
# wed                                              -0.160753
# thurs                                            -0.091602
# ...                                                    ...
# term_fall                                        -0.034414
# term_spring                                       0.034414
# course_difficulty_advanced                        1.000000
# course_difficulty_elementary                     -0.437640
# course_difficulty_intermediate                   -0.419209
#
#                                 course_difficulty_elementary  \
# start_time                                          0.058485
# mon                                                 0.231860
# tues                                                0.050282
# wed                                                 0.182533
# thurs                                               0.066410
# ...                                                      ...
# term_fall                                           0.048725
# term_spring                                        -0.048725
# course_difficulty_advanced                         -0.437640
# course_difficulty_elementary                        1.000000
# course_difficulty_intermediate                     -0.632867
#
#                                 course_difficulty_intermediate
# start_time                                            0.056868
# mon                                                  -0.072834
# tues                                                  0.017370
# wed                                                  -0.045882
# thurs                                                 0.011824
# ...                                                        ...
# term_fall                                            -0.019564
# term_spring                                           0.019564
# course_difficulty_advanced                           -0.419209
# course_difficulty_elementary                         -0.632867
# course_difficulty_intermediate                        1.000000
#
# [1378 rows x 1378 columns]

# %%
# too many columns to visualize in heatmap; will look at coefficients in tables instead
corr_coefficients = corr.unstack().sort_values().drop_duplicates()

print(type(corr_coefficients))

# most strongly correlated variables (negative)
display(corr_coefficients.head())

# most strongly correlated variables (positive)
display(corr_coefficients.tail())
# Out:
# <class 'pandas.core.series.Series'>
# term_spring                     term_fall                      -1.000000
# section_type_lab                section_type_lec               -0.650262
# course_difficulty_intermediate  course_difficulty_elementary   -0.632867
# section_type_ind                start_time                     -0.554149
# wed                             tues                           -0.550931
# dtype: float64
# instructor_id_309711.0                                              course_name_nutrition today                                0.984941
# course_name_workshop in educational leadership and policy analysis  subject_name_educational leadership and policy analysis    0.985174
# instructor_id_464620.0                                              course_name_business law                                   0.986384
# facility_code_0129                                                  subject_name_naval science                                 0.995814
# course_difficulty_elementary                                        course_difficulty_elementary                               1.000000
# dtype: float64

# %%
corr_df = corr_coefficients.to_frame()
corr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 527506 entries, ('term_spring', 'term_fall') to ('course_difficulty_elementary', 'course_difficulty_elementary')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       527506 non-null  float64
# dtypes: float64(1)
# memory usage: 6.1+ MB

# %%
corr_df.head()
# Out:
#                                                                     0
# term_spring                    term_fall                    -1.000000
# section_type_lab               section_type_lec             -0.650262
# course_difficulty_intermediate course_difficulty_elementary -0.632867
# section_type_ind               start_time                   -0.554149
# wed                            tues                         -0.550931

# %%
corr_df.rename(columns = {0: 'coeff'}, inplace = True)

# %%
# positive strong correlations
strong_pos = corr_df[corr_df['coeff'] >= .7]

with pd.option_context('display.max_rows', None):
    print(strong_pos)
# Out:
#                                                                                                           coeff
# course_name_nuclear reactor laboratory             instructor_id_599888.0                              0.700496
# course_name_elementary latin                       subject_name_latin (classics)                       0.700620
# subject_name_community and environmental sociology instructor_id_2601467.0                             0.701736
# course_name_human resources development: educat... subject_name_counseling psychology                  0.704337
# subject_name_biological systems engineering        facility_code_0080                                  0.705713
# course_name_bank management                        instructor_id_747510.0                              0.707842
# instructor_id_190420.0                             course_name_issues in psychology                    0.709151
# course_name_introduction to scientific communic... instructor_id_280437.0                              0.711793
# subject_name_communication arts                    course_name_introduction to speech composition      0.714968
# instructor_id_5476239.0                            course_name_wes-cs group meeting                    0.719860
# subject_name_materials science and engineering     facility_code_0520                                  0.725457
# course_name_professional communication             subject_name_general business                       0.726487
# instructor_id_2600012.0                            course_name_biomedical engineering design           0.733665
# subject_name_physiology                            course_name_selected topics in physiology           0.734413
# facility_code_0153                                 subject_name_curriculum and instruction             0.737997
# facility_code_0468                                 subject_name_oncology                               0.745109
# course_name_general microbiology laboratory        instructor_id_807999.0                              0.747609
# subject_name_physics                               facility_code_0055                                  0.750682
# instructor_id_710039.0                             course_name_introductory microprocessor laboratory  0.750937
# subject_name_american indian studies               course_name_issues in american indian studies       0.757627
# facility_code_0048                                 subject_name_mathematics                            0.758215
# subject_name_kinesiology                           facility_code_0031                                  0.759141
# instructor_id_573312.0                             course_name_black music and american cultural h...  0.760762
# instructor_id_464468.0                             course_name_food service operations lab             0.768494
# wed                                                mon                                                 0.771070
# course_name_rhythmic/step aerobics                 instructor_id_716313.0                              0.777867
# instructor_id_105416.0                             course_name_practical french conversation           0.779271
# course_name_contemporary topics in urban and re... facility_code_0485                                  0.786389
# facility_code_0025                                 instructor_id_319547.0                              0.790579
# instructor_id_526677.0                             facility_code_0038                                  0.806872
# instructor_id_810900.0                             course_name_residential property development        0.810002
# course_name_legal sources                          subject_name_law                                    0.811387
# course_name_introduction to contemporary afro-a... instructor_id_2601801.0                             0.816405
# subject_name_law                                   facility_code_0430                                  0.819669
# subject_name_geoscience                            facility_code_0521                                  0.819777
# instructor_id_921047.0                             course_name_introduction to martial arts            0.821113
# subject_name_physical therapy                      instructor_id_3013999.0                             0.823270
# course_name_topics in anatomy                      subject_name_anatomy                                0.825605
# tues                                               thurs                                               0.829200
# subject_name_life sciences communication           facility_code_0076                                  0.835372
# instructor_id_4539921.0                            course_name_marketing management                    0.836484
# course_name_editing and post-production for vid... instructor_id_3333089.0                             0.836583
# course_name_business statistics                    instructor_id_809212.0                              0.837049
# facility_code_0505                                 course_name_bowling i                               0.845085
# course_name_operations management                  instructor_id_3011973.0                             0.854382
# facility_code_1095                                 subject_name_air force aerospace studies            0.857414
# course_name_contemporary topics in urban and re... subject_name_urban and regional planning            0.865919
# a_proportion                                       avg_grade                                           0.873959
# instructor_id_156269.0                             subject_name_international business                 0.878959
# subject_name_international business                course_name_international business                  0.878959
# course_name_financial statement analysis           instructor_id_659531.0                              0.882365
# facility_code_0032                                 subject_name_dance                                  0.883792
# course_name_biomechanics of human movement         instructor_id_2600918.0                             0.883909
# course_name_topics in fencing                      instructor_id_562884.0                              0.891069
# facility_code_0047                                 subject_name_chemistry                              0.896170
# instructor_id_146785.0                             course_name_ensemble: wisconsin singers             0.900386
# course_name_accounting systems                     instructor_id_3076440.0                             0.909625
# subject_name_urban and regional planning           facility_code_0485                                  0.914649
# instructor_id_3216300.0                            course_name_introductory organic chemistry labo...  0.923202
# facility_code_0544                                 subject_name_art history                            0.927386
# subject_name_atmospheric and oceanic sciences      facility_code_0156                                  0.937379
# course_name_the biology and appreciation of com... instructor_id_2601788.0                             0.938054
# instructor_id_880292.0                             course_name_money and banking                       0.954525
# instructor_id_2601129.0                            course_name_financial markets, institutions and...  0.981970
# instructor_id_309711.0                             course_name_nutrition today                         0.984941
# course_name_workshop in educational leadership ... subject_name_educational leadership and policy ...  0.985174
# instructor_id_464620.0                             course_name_business law                            0.986384
# facility_code_0129                                 subject_name_naval science                          0.995814
# course_difficulty_elementary                       course_difficulty_elementary                        1.000000

# %%
# positive moderate correlations
mod_pos = corr_df[ (corr_df['coeff'] >= .5) & (corr_df['coeff'] < .7) ]

with pd.option_context('display.max_rows', None):
    print(mod_pos)
# Out:
#                                                                                                           coeff
# instructor_id_4197612.0                            course_name_transitions: practice, professional...  0.500293
# course_name_introduction to statistical methods    facility_code_0451a                                 0.501300
# instructor_id_1600979.0                            course_name_survey of early hispanic literature     0.502305
# facility_code_0557                                 course_name_crc first-year seminar: foundations...  0.502439
# subject_name_physical therapy                      course_name_physical therapy educcation and lif...  0.502532
# instructor_id_590681.0                             course_name_human resources development: career...  0.502685
# course_name_second semester hebrew                 instructor_id_1062990.0                             0.503713
# instructor_id_3370746.0                            subject_name_occupational therapy (department o...  0.504802
# instructor_id_318683.0                             course_name_statics                                 0.506741
# course_name_corporation finance                    subject_name_finance, investment and banking        0.507190
# section_type_lab                                   subject_name_art department                         0.509028
# facility_code_0503                                 subject_name_air force aerospace studies            0.514364
# instructor_id_623712.0                             course_name_clinical iii: community health nurs...  0.515783
# subject_name_physical therapy                      facility_code_0450                                  0.516732
# instructor_id_2600609.0                            course_name_color                                   0.516902
# course_name_managing organizations                 instructor_id_5614845.0                             0.522283
# subject_name_agricultural and applied economics    facility_code_0464                                  0.522319
# facility_code_0070                                 subject_name_landscape architecture                 0.524319
# subject_name_educational psychology                course_name_contemporary issues in educational ...  0.524510
# facility_code_0087c                                subject_name_horticulture                           0.525043
# instructor_id_3922122.0                            course_name_ensemble-brass                          0.526577
# course_name_introduction to acting                 subject_name_theatre and drama                      0.528844
# instructor_id_671929.0                             course_name_production planning and control         0.530061
# facility_code_0085                                 subject_name_design studies                         0.531499
# mon                                                fri                                                 0.532388
# course_name_hydroscience                           instructor_id_345391.0                              0.533251
# instructor_id_526677.0                             course_name_tennis i                                0.534108
# instructor_id_2600039.0                            subject_name_educational psychology                 0.534140
# subject_name_educational psychology                course_name_independent reading undergrad           0.534140
# subject_name_engineering professional development  facility_code_0481                                  0.534344
# subject_name_mechanical engineering                facility_code_0407                                  0.535747
# course_name_first semester greek                   subject_name_greek (classics)                       0.535878
# course_name_cross traing-basic fitness             facility_code_0025                                  0.536492
# facility_code_1480                                 subject_name_physician assistant program            0.536729
# course_name_independent work                       subject_name_physiology                             0.538084
# course_name_the evolving universe: stars, galax... subject_name_astronomy                              0.538689
# facility_code_0205                                 subject_name_biochemistry                           0.540466
# subject_name_environmental studies - gaylord ne... course_name_special topics: social perspectives...  0.542226
# course_name_actuarial mathematics i                instructor_id_654739.0                              0.543335
# subject_name_neuroscience                          course_name_independent work                        0.545105
# facility_code_0028                                 subject_name_physical educ activity progm           0.546671
# facility_code_0082                                 subject_name_genetics                               0.548734
# instructor_id_350836.0                             subject_name_hebrew-modern                          0.550353
# instructor_id_2600012.0                            subject_name_biomedical engineering                 0.551483
# course_name_bowling i                              instructor_id_2601706.0                             0.553088
# instructor_id_377240.0                             course_name_ensemble-string                         0.554019
# instructor_id_2602103.0                            course_name_survey of the history of western music  0.554109
# instructor_id_618034.0                             facility_code_0038                                  0.557988
# course_name_first semester italian                 subject_name_italian (french and italian)           0.558827
# course_name_applied mathematical analysis          instructor_id_2600056.0                             0.559009
# subject_name_asian american studies                course_name_topics in asian american studies        0.561579
# facility_code_0545                                 course_name_introduction to speech composition      0.562935
# instructor_id_350836.0                             course_name_first semester hebrew                   0.566931
# instructor_id_3234517.0                            course_name_quantitative reasoning and problem ...  0.567711
# course_name_history of ancient philosophy          instructor_id_2600182.0                             0.569580
# course_name_engineering design projects            instructor_id_783847.0                              0.569746
# facility_code_0451a                                subject_name_statistics                             0.572117
# instructor_id_319547.0                             course_name_ice skating i                           0.577032
# course_name_special topics in construction engi... instructor_id_2601502.0                             0.579892
# subject_name_hebrew                                instructor_id_1062990.0                             0.580633
# instructor_id_2600039.0                            course_name_contemporary issues in educational ...  0.581680
# subject_name_legal studies                         course_name_topics in legal studies and the hum...  0.584027
# course_name_basic communication                    facility_code_0481                                  0.584228
# instructor_id_1088502.0                            course_name_media and human behavior                0.585168
# course_name_directed study in research             subject_name_neuroscience training program          0.585378
# instructor_id_5108957.0                            course_name_advanced financial reporting            0.587661
# instructor_id_714123.0                             subject_name_dairy science                          0.589832
# instructor_id_718942.0                             course_name_creative campaign messages              0.590625
# facility_code_1485                                 subject_name_medical physics                        0.591080
# subject_name_medical genetics                      course_name_independent reading                     0.593204
# course_name_topics in contemporary social welfare  instructor_id_3673656.0                             0.593655
# course_name_first semester hebrew                  subject_name_hebrew                                 0.594025
# subject_name_engineering professional development  course_name_technical communication                 0.594942
# instructor_id_839802.0                             course_name_hands on the universe                   0.597413
# course_name_introduction to art                    instructor_id_253246.0                              0.604339
# subject_name_soil science                          facility_code_0074b                                 0.607269
# instructor_id_623858.0                             subject_name_genetics                               0.612584
# course_name_tennis ii                              facility_code_0038                                  0.613396
# course_name_operations management                  subject_name_operations and technology management   0.615315
# instructor_id_3011973.0                            subject_name_operations and technology management   0.615315
# course_name_musica practica 1                      instructor_id_2600807.0                             0.616606
# instructor_id_899785.0                             course_name_transport phenomena lab                 0.617649
# course_name_genetics laboratory                    facility_code_0082                                  0.620786
# facility_code_0155                                 subject_name_computer sciences                      0.622707
# course_name_directed studies in zoology            subject_name_zoology                                0.623735
# course_name_topics in legal studies and the soc... subject_name_legal studies                          0.624376
# subject_name_surgical sciences                     facility_code_0093                                  0.624768
# course_name_jazz ensemble                          instructor_id_5104316.0                             0.625333
# subject_name_food science                          instructor_id_464468.0                              0.626130
# instructor_id_423731.0                             course_name_pedagogical theory and practice for...  0.628772
# subject_name_communication sciences and disorders  facility_code_0508                                  0.633980
# course_name_genetics laboratory                    instructor_id_135311.0                              0.641877
# course_name_conducting                             instructor_id_4197306.0                             0.642347
# course_name_human resource management              instructor_id_717098.0                              0.642908
# instructor_id_496397.0                             course_name_first aid and basic life support        0.643870
# instructor_id_447664.0                             course_name_intermediate german-reading             0.645702
# instructor_id_377240.0                             course_name_advanced ensemble-string                0.647329
# class_length                                       total_time                                          0.647715
# facility_code_0106                                 subject_name_food science                           0.652819
# facility_code_0060                                 subject_name_microbiology                           0.655070
# course_name_internship in rehabilitation or spe... instructor_id_441546.0                              0.655565
# facility_code_0545                                 subject_name_communication arts                     0.657489
# subject_name_pharmacy practice                     facility_code_0034                                  0.660895
# subject_name_social work                           facility_code_0453                                  0.662636
# course_name_legal sources                          facility_code_0430                                  0.665068
# instructor_id_4384631.0                            course_name_theory and practice of persuasion       0.665768
# facility_code_0114                                 subject_name_forest and wildlife ecology            0.666086
# facility_code_0451c                                course_name_undergraduate neurobiology seminar      0.666678
# instructor_id_2601068.0                            course_name_optoelectronics lab                     0.673932
# instructor_id_2601066.0                            course_name_seminar-transportation engineering      0.676175
# instructor_id_565790.0                             course_name_research methods                        0.677906
# subject_name_psychology                            facility_code_0470                                  0.678282
# course_name_school and society                     subject_name_educational policy studies             0.678444
# facility_code_0053                                 subject_name_geography                              0.680656
# course_name_music in performance                   instructor_id_335843.0                              0.681675
# course_name_human language                         instructor_id_950705.0                              0.681675
# facility_code_0038                                 course_name_tennis i                                0.683477
# instructor_id_366212.0                             course_name_teaching science                        0.683993
# subject_name_nutritional sciences                  course_name_nutrition today                         0.685793
# instructor_id_697108.0                             course_name_racquetball i                           0.685805
# course_name_musica practica 3                      instructor_id_2600759.0                             0.691395
# instructor_id_159304.0                             course_name_intro to yoga practice                  0.692522
# course_name_engineering design with polymers       instructor_id_965150.0                              0.693184
# instructor_id_309711.0                             subject_name_nutritional sciences                   0.696278
# course_name_golf i                                 instructor_id_2601242.0                             0.698166

# %%
# positive low correlations
low_pos = corr_df[ (corr_df['coeff'] >= .3) & (corr_df['coeff'] < .5) ]

with pd.option_context('display.max_rows', None):
    print(low_pos)
# Out:
#                                                                                                           coeff
# subject_name_mechanical engineering                course_name_engineering design projects             0.300193
# facility_code_0028                                 instructor_id_716313.0                              0.300207
# instructor_id_2601788.0                            facility_code_0118                                  0.301437
# facility_code_0450                                 course_name_physical therapy educcation and lif...  0.301460
# instructor_id_4942976.0                            course_name_managing organizations                  0.301866
# subject_name_curriculum and instruction            course_name_general seminar                         0.301946
# course_name_special topics in mass communication   instructor_id_2601747.0                             0.302277
# facility_code_1480                                 instructor_id_585086.0                              0.302475
# instructor_id_899785.0                             subject_name_chemical and biological engineering    0.302601
# instructor_id_309711.0                             facility_code_0070                                  0.302746
# course_name_fourth semester german                 subject_name_german                                 0.303435
# subject_name_computer sciences                     course_name_wes-cs group meeting                    0.303618
# course_name_first semester norwegian               subject_name_scandinavian studies                   0.304006
# facility_code_0038                                 subject_name_physical educ activity progm           0.304100
# course_name_basic statistics for psychology        subject_name_psychology                             0.304477
# subject_name_nursing                               course_name_nursing care of persons and familie...  0.304838
# instructor_id_3669416.0                            course_name_elementary heat transfer                0.305968
# subject_name_portuguese (spanish and portuguese)   instructor_id_4174092.0                             0.306239
# course_name_fourth year composition and convers... subject_name_portuguese (spanish and portuguese)    0.306239
# section_type_lab                                   facility_code_0469                                  0.306292
# subject_name_engineering mechanics and astronau... course_name_practicum in finite elements            0.306617
# course_name_racquetball i                          facility_code_0028                                  0.306667
# subject_name_management and human resources        instructor_id_717098.0                              0.306693
# facility_code_0031                                 subject_name_physical educ activity progm           0.306732
# course_name_food service operations lab            facility_code_0106                                  0.306864
# course_name_problems in developmental psychology   instructor_id_2601570.0                             0.307243
# subject_name_chemistry                             course_name_general chemistry i                     0.307245
# course_name_introductory organic chemistry         subject_name_chemistry                              0.307245
# instructor_id_4611259.0                            course_name_introduction to acting                  0.307331
# course_name_nutrition today                        facility_code_0070                                  0.307448
# instructor_id_984470.0                             subject_name_kinesiology                            0.308173
# subject_name_comparative biosciences               facility_code_0093                                  0.308421
# facility_code_0032                                 instructor_id_3382514.0                             0.309399
# course_name_thermodynamics                         instructor_id_728205.0                              0.309421
# subject_name_marketing                             course_name_strategic retailing                     0.309428
#                                                    instructor_id_246667.0                              0.309428
# course_name_financial reporting ii                 instructor_id_5108957.0                             0.310175
# course_name_second semester spanish                subject_name_spanish (spanish and portuguese)       0.310412
# facility_code_0114                                 subject_name_entomology                             0.310572
# instructor_id_464468.0                             facility_code_0106                                  0.310609
# course_name_introduction to chinese linguistics    instructor_id_2601970.0                             0.310872
# subject_name_afro-american studies                 course_name_introduction to afro-american history   0.311184
# course_name_mechanical engineering projects i      instructor_id_663146.0                              0.311453
# course_name_introductory statistics for engineers  instructor_id_393380.0                              0.311610
# subject_name_chemical and biological engineering   course_name_transport phenomena lab                 0.311642
#                                                    instructor_id_2601947.0                             0.311642
# subject_name_physical educ activity progm          instructor_id_319547.0                              0.311911
# course_name_intermediate macroeconomic theory      subject_name_economics                              0.312390
# facility_code_0140                                 subject_name_management and human resources         0.312699
# course_name_drawing i                              subject_name_art department                         0.312707
# course_name_introduction to college composition    subject_name_english                                0.312799
# subject_name_geography                             instructor_id_2600409.0                             0.313119
# course_name_third semester portuguese              subject_name_portuguese (spanish and portuguese)    0.313448
# subject_name_medical physics                       facility_code_1404k                                 0.313449
# instructor_id_470563.0                             subject_name_engineering mechanics and astronau...  0.313511
# course_name_leadership and teamwork                facility_code_0103                                  0.313615
# instructor_id_496397.0                             subject_name_kinesiology                            0.313641
# subject_name_music                                 section_type_dis                                    0.313730
# instructor_id_2600361.0                            subject_name_finance, investment and banking        0.313742
# subject_name_medical sciences - veterinary medi... facility_code_0093                                  0.313911
# course_name_generalist practice with communitie... instructor_id_4699168.0                             0.314534
# instructor_id_3044764.0                            course_name_geometric modeling for engineering ...  0.314666
# course_name_introductory experience in electric... instructor_id_566960.0                              0.314860
# instructor_id_795078.0                             course_name_current topics in psychology            0.314872
# facility_code_0470                                 course_name_basic statistics for psychology         0.315206
# subject_name_anthropology                          course_name_cultural anthropology and human div...  0.315422
# subject_name_biological systems engineering        facility_code_0099                                  0.315449
# course_name_introduction to digital forms          facility_code_0153                                  0.315469
# instructor_id_143932.0                             course_name_introduction to statistical methods     0.315628
# subject_name_slavic (slavic languages)             course_name_second semester russian                 0.315664
# instructor_id_426165.0                             course_name_intermediate painting i                 0.316372
# course_name_consumer behavior                      subject_name_marketing                              0.316457
# instructor_id_3013497.0                            subject_name_scandinavian studies                   0.317648
# facility_code_0123                                 subject_name_animal sciences                        0.318315
# course_name_introduction to data structures        subject_name_computer sciences                      0.318453
# subject_name_afro-american studies                 course_name_introduction to contemporary afro-a...  0.318510
# course_name_black music and american cultural h... subject_name_afro-american studies                  0.318510
# course_name_third semester german                  subject_name_german                                 0.319032
# instructor_id_807999.0                             facility_code_0060                                  0.319164
# subject_name_history of science                    facility_code_0452                                  0.319268
# instructor_id_2601706.0                            subject_name_physical educ activity progm           0.319533
# course_name_intermediate microeconomic theory      subject_name_economics                              0.319748
# subject_name_economics                             instructor_id_2601630.0                             0.319748
# instructor_id_2601502.0                            subject_name_civil and environmental engineering    0.319801
# instructor_id_4109651.0                            subject_name_communication sciences and disorders   0.319829
# subject_name_counseling psychology                 instructor_id_3615604.0                             0.319954
#                                                    course_name_human resources develop: awareness ...  0.319954
# instructor_id_556159.0                             subject_name_slavic (slavic languages)              0.320145
# subject_name_chemical and biological engineering   instructor_id_2601894.0                             0.320429
# instructor_id_2602001.0                            subject_name_greek (classics)                       0.320635
# facility_code_0011                                 subject_name_medical sciences - veterinary medi...  0.321195
# subject_name_marketing                             facility_code_0140                                  0.321245
#                                                    instructor_id_4539921.0                             0.321420
# course_name_introductory statistics for engineers  subject_name_statistics                             0.321499
# course_name_the biology and appreciation of com... facility_code_0118                                  0.321514
# instructor_id_712293.0                             subject_name_life sciences communication            0.321578
# subject_name_life sciences communication           course_name_introduction to scientific communic...  0.321578
# course_name_fundamentals of analytical science     instructor_id_714165.0                              0.321613
# instructor_id_2600213.0                            subject_name_materials science and engineering      0.322108
# subject_name_human development and family studies  course_name_racial ethnic families in the u.s.      0.322716
# instructor_id_3437415.0                            course_name_topics in spanish language practice     0.323933
# instructor_id_2601947.0                            course_name_momentum and heat transfer operations   0.323960
# course_name_intermediate composition               facility_code_0018                                  0.323981
# instructor_id_960897.0                             course_name_problem solving using computers         0.324022
# instructor_id_428512.0                             course_name_advanced conversation                   0.324143
# instructor_id_225350.0                             course_name_survey of early hispanic literature     0.324777
# course_name_advanced independent study             instructor_id_2600861.0                             0.324913
# facility_code_0055                                 course_name_general physics                         0.325111
# course_name_cultural anthropology: theory and e... instructor_id_3484297.0                             0.325374
# total_time                                         subject_name_medical sciences - veterinary medi...  0.325500
# course_name_entrepreneurial management             subject_name_management and human resources         0.326264
# course_name_human resource management              subject_name_management and human resources         0.326264
# course_name_fundamentals of acting                 instructor_id_2602091.0                             0.326442
# subject_name_rehabilitation psychology and spec... course_name_individuals with disabilities           0.326576
# subject_name_design studies                        instructor_id_3922123.0                             0.326931
# course_name_directed creative writing              instructor_id_1005574.0                             0.327405
# instructor_id_1127599.0                            subject_name_languages and cultures of asia - l...  0.327534
# instructor_id_3615604.0                            facility_code_0021                                  0.327548
# instructor_id_2601091.0                            course_name_introductory applied statistics for...  0.327671
# subject_name_astronomy                             facility_code_0057                                  0.327797
# instructor_id_2600409.0                            course_name_introduction to human geography         0.327911
# course_name_crc first-year seminar: foundations... facility_code_0560                                  0.327936
# subject_name_greek (classics)                      instructor_id_508990.0                              0.328321
# instructor_id_671929.0                             subject_name_industrial and systems engineering     0.328381
# instructor_id_650044.0                             facility_code_0481                                  0.328436
# course_name_crc first-year seminar: foundations... subject_name_integrated liberal studies             0.328561
# facility_code_0031                                 instructor_id_496397.0                              0.329215
# instructor_id_5124092.0                            course_name_foundations of officership              0.329797
# subject_name_civil and environmental engineering   facility_code_0408                                  0.330091
# facility_code_0482                                 subject_name_french (french and italian)            0.330612
# subject_name_french (french and italian)           course_name_fourth semester french                  0.330713
# instructor_id_3560127.0                            course_name_individuals with disabilities           0.330726
# course_name_clinical iii: community health nurs... subject_name_nursing                                0.331882
# facility_code_0103                                 course_name_individual leadership studies           0.331909
# course_name_financial markets, institutions and... subject_name_finance, investment and banking        0.331912
# course_name_second semester french                 subject_name_french (french and italian)            0.331930
# instructor_id_3382514.0                            subject_name_dance                                  0.332318
# instructor_id_426165.0                             course_name_advanced undergraduate painting wor...  0.332565
# instructor_id_1005245.0                            subject_name_civil and environmental engineering    0.332666
# instructor_id_832223.0                             course_name_special topics in gender, women and...  0.333038
# instructor_id_117305.0                             course_name_capstone seminar in gender and wome...  0.333297
# subject_name_theatre and drama                     course_name_special topics in theatre and drama     0.333632
# course_name_rhythmic/step aerobics                 instructor_id_302280.0                              0.333636
# course_name_digital tools, trends and debates      instructor_id_235413.0                              0.333886
# course_name_basic statistics for psychology        instructor_id_165539.0                              0.333950
# instructor_id_3370746.0                            facility_code_0450                                  0.333982
# course_name_special topics in integrated libera... facility_code_0035                                  0.334289
# course_name_theatre production laboratory          instructor_id_3659559.0                             0.335054
# instructor_id_146785.0                             weekend                                             0.335655
# instructor_id_740536.0                             subject_name_pharmacy practice                      0.335663
# course_name_second semester german                 subject_name_german                                 0.335719
# course_name_problems of american racial and eth... subject_name_sociology                              0.336346
# subject_name_consumer science                      instructor_id_631912.0                              0.336482
# course_name_weight training                        subject_name_physical educ activity progm           0.337841
# subject_name_finance, investment and banking       instructor_id_2601129.0                             0.338006
# course_name_biology of microorganisms laboratory   instructor_id_446645.0                              0.339047
# course_name_internship in rehabilitation or spe... subject_name_rehabilitation psychology and spec...  0.339233
# facility_code_0070                                 instructor_id_2601878.0                             0.340098
# subject_name_therapeutic science (department of... facility_code_0450                                  0.340265
# subject_name_chemical and biological engineering   facility_code_0408                                  0.340459
# instructor_id_133526.0                             course_name_biology of microorganisms laboratory    0.340654
# subject_name_accounting and information systems    course_name_introductory managerial accounting      0.340686
# instructor_id_2600699.0                            subject_name_portuguese (spanish and portuguese)    0.340768
# course_name_introduction to italian literature     instructor_id_2600112.0                             0.340806
# course_name_musica practica: aural skills 4        section_type_dis                                    0.340825
# subject_name_journalism and mass communication     course_name_special topics in mass communication    0.341079
# course_name_special topics in film                 instructor_id_527820.0                              0.341300
# course_name_special topics in chemical engineering subject_name_chemical and biological engineering    0.341411
# subject_name_french (french and italian)           course_name_third semester french                   0.341511
# course_name_second semester hebrew                 instructor_id_350836.0                              0.341533
# instructor_id_999979.0                             facility_code_0028                                  0.342885
# instructor_id_465586.0                             subject_name_life sciences communication            0.343053
# instructor_id_900201.0                             course_name_basic statistics for psychology         0.343086
# course_name_introduction to communicative disor... subject_name_communication sciences and disorders   0.343565
# facility_code_0103                                 instructor_id_5124092.0                             0.343565
# instructor_id_2602098.0                            course_name_practicum in finite elements            0.345373
# subject_name_chemical and biological engineering   instructor_id_2601181.0                             0.345455
# facility_code_0087a                                subject_name_horticulture                           0.345535
# subject_name_biology                               facility_code_0102                                  0.345574
# instructor_id_2601788.0                            facility_code_0110                                  0.346332
# course_name_statistics: measurement in economics   instructor_id_4916562.0                             0.346841
# facility_code_0076                                 instructor_id_280437.0                              0.346934
# course_name_contemporary practices in nursing      subject_name_nursing                                0.347101
# course_name_biology of microorganisms laboratory   instructor_id_573481.0                              0.347725
# course_name_algebra                                subject_name_mathematics                            0.347774
# instructor_id_2600679.0                            course_name_introduction to modern physics          0.347850
# instructor_id_315329.0                             course_name_issues in american indian studies       0.348045
# instructor_id_4232086.0                            subject_name_dance                                  0.348559
# course_name_history of western art ii: from ren... instructor_id_958256.0                              0.348845
# facility_code_0451c                                subject_name_neuroscience training program          0.350441
# course_name_loss models i                          subject_name_actuarial science                      0.350933
# subject_name_gender and women’s studies            course_name_special topics in gender, women and...  0.351397
# course_name_introduction to programming            subject_name_computer sciences                      0.351524
# facility_code_0469                                 subject_name_history                                0.352283
# instructor_id_3215013.0                            course_name_fundamentals of acting                  0.352416
# subject_name_integrated liberal studies            course_name_special topics in integrated libera...  0.352592
# instructor_id_1076688.0                            subject_name_dairy science                          0.352833
# course_name_field practice and integrative semi... facility_code_0453                                  0.354597
# course_name_marketing research                     subject_name_marketing                              0.354982
# subject_name_sociology                             course_name_classical sociological theory           0.355146
# subject_name_forest and wildlife ecology           instructor_id_3031297.0                             0.355362
# course_name_current topics in dance: workshop      instructor_id_4232086.0                             0.355963
# subject_name_management and human resources        instructor_id_342827.0                              0.356108
# instructor_id_3232267.0                            subject_name_history of science                     0.357318
# instructor_id_2600729.0                            course_name_elementary/intermediate voice           0.357890
# subject_name_engineering mechanics and astronau... instructor_id_318683.0                              0.358081
# instructor_id_2602053.0                            subject_name_engineering mechanics and astronau...  0.358219
# instructor_id_2601850.0                            course_name_advanced undergraduate painting wor...  0.358430
# course_name_consumer finance                       subject_name_consumer science                       0.358447
# instructor_id_3105692.0                            course_name_professional communication              0.358862
# course_name_actuarial mathematics i                subject_name_actuarial science                      0.359195
# instructor_id_682267.0                             subject_name_human development and family studies   0.359383
# course_name_introductory ethics                    instructor_id_807290.0                              0.359847
# instructor_id_2601973.0                            course_name_introduction to american politics a...  0.359962
# course_name_theme in 19th c amer lit               instructor_id_2600783.0                             0.360018
# subject_name_music-performance                     course_name_elementary/intermediate voice           0.360168
# course_name_structure of english                   instructor_id_3214961.0                             0.360484
# subject_name_social work                           course_name_field practice and integrative semi...  0.360794
# course_name_first semester norwegian               instructor_id_692771.0                              0.361489
# course_name_intermediate latin                     subject_name_latin (classics)                       0.361555
# course_name_marketing strategy                     subject_name_marketing                              0.362019
# instructor_id_4753016.0                            course_name_introduction to interpersonal commu...  0.362299
# facility_code_0035                                 subject_name_integrated liberal studies             0.362507
# course_name_principles and practices of reporting  subject_name_journalism and mass communication      0.363136
# instructor_id_623858.0                             subject_name_medical genetics                       0.363313
# instructor_id_2602098.0                            course_name_statics                                 0.363442
# course_name_information technology, risk, and a... instructor_id_673502.0                              0.363727
# course_name_the making of modern europe 1500-1815  instructor_id_2602170.0                             0.363727
# subject_name_engineering professional development  course_name_technical presentations                 0.363925
# course_name_directed studies in zoology            instructor_id_2600921.0                             0.364060
# subject_name_accounting and information systems    course_name_financial reporting i                   0.364527
# instructor_id_673502.0                             course_name_audit and assurance services            0.364569
# course_name_weight training                        facility_code_0028                                  0.365072
# subject_name_physical educ activity progm          facility_code_0025                                  0.365244
# course_name_marketing management                   subject_name_marketing                              0.365487
# course_name_fourth semester spanish                subject_name_spanish (spanish and portuguese)       0.365629
# subject_name_nuclear engineering                   instructor_id_599888.0                              0.365729
# facility_code_0469                                 subject_name_music                                  0.365744
# subject_name_physics                               course_name_general physics                         0.365906
# facility_code_0560                                 instructor_id_685141.0                              0.366125
# instructor_id_3356405.0                            subject_name_landscape architecture                 0.366192
# course_name_survey of spanish american literature  instructor_id_3233889.0                             0.366428
# facility_code_0449                                 subject_name_nutritional sciences                   0.367711
# subject_name_microbiology                          instructor_id_446645.0                              0.368358
# instructor_id_4841162.0                            course_name_life drawing i                          0.368521
# instructor_id_977376.0                             subject_name_risk management and insurance          0.369277
# course_name_technical communication                instructor_id_2601527.0                             0.369540
# subject_name_dairy science                         facility_code_0118                                  0.369618
# course_name_wes-cs group meeting                   instructor_id_140460.0                              0.369935
# course_name_generalist practice with communitie... instructor_id_257427.0                              0.370021
# course_name_running (aerobic fitness)              instructor_id_319547.0                              0.370204
# course_name_human resources development: career... subject_name_counseling psychology                  0.370274
# course_name_wes-cs group meeting                   facility_code_0155                                  0.370461
# instructor_id_685141.0                             course_name_crc first-year seminar: foundations...  0.371654
# instructor_id_1591621.0                            course_name_theory and practice of group discus...  0.371918
# subject_name_geoscience                            course_name_evolution and extinction                0.372631
# instructor_id_3128595.0                            course_name_survey of japanese literature           0.372789
# course_name_survey of japanese literature in tr... instructor_id_3128595.0                             0.372789
# weekend                                            course_name_ensemble: wisconsin singers             0.372790
# instructor_id_4449171.0                            course_name_basic leadership                        0.372887
# subject_name_life sciences communication           course_name_science and storytelling                0.372961
# course_name_special topics in industrial engine... subject_name_industrial and systems engineering     0.374313
# course_name_general microbiology laboratory        facility_code_0060                                  0.375148
# subject_name_actuarial science                     instructor_id_654739.0                              0.375430
# instructor_id_2602098.0                            subject_name_engineering mechanics and astronau...  0.375668
# instructor_id_685944.0                             total_time                                          0.376224
# subject_name_microbiology                          instructor_id_573481.0                              0.376288
# instructor_id_4678634.0                            course_name_introduction to chinese linguistics     0.376555
# course_name_in translation: the tales of hans c... instructor_id_3013497.0                             0.377374
# instructor_id_2600795.0                            facility_code_0220                                  0.377478
# instructor_id_3213517.0                            subject_name_classics                               0.377788
# instructor_id_3214633.0                            subject_name_comparative literature                 0.378613
# instructor_id_950705.0                             subject_name_linguistics                            0.378690
# subject_name_linguistics                           course_name_human language                          0.378690
# course_name_introduction to agricultural and ap... instructor_id_2600954.0                             0.378716
# subject_name_anthropology                          facility_code_0046                                  0.379086
# facility_code_0076                                 course_name_introduction to scientific communic...  0.379173
# instructor_id_2601686.0                            course_name_intro to modern american lit            0.379541
# course_name_first semester german                  subject_name_german                                 0.379860
# instructor_id_815179.0                             course_name_special topics: social perspectives...  0.381122
# instructor_id_4397528.0                            subject_name_communication sciences and disorders   0.381576
# facility_code_0103                                 course_name_basic leadership                        0.381576
# instructor_id_2600403.0                            course_name_directed study in research              0.381951
# subject_name_statistics                            course_name_introductory applied statistics for...  0.382079
# facility_code_0557                                 instructor_id_4530799.0                             0.382405
# subject_name_spanish (spanish and portuguese)      course_name_intermediate language practice with...  0.382459
# instructor_id_3374762.0                            course_name_relief printmaking                      0.382594
# course_name_introduction to american politics a... instructor_id_2600859.0                             0.382770
# instructor_id_684778.0                             course_name_life drawing i                          0.382858
# subject_name_italian (french and italian)          course_name_third semester italian                  0.383439
# course_name_hydroscience                           instructor_id_2601522.0                             0.383467
# instructor_id_133526.0                             subject_name_microbiology                           0.384055
# subject_name_afro-american studies                 instructor_id_408564.0                              0.384177
# facility_code_0140                                 subject_name_general business                       0.384306
# instructor_id_2601244.0                            course_name_electrodynamics i                       0.384872
# course_name_biology of microorganisms laboratory   facility_code_0060                                  0.384939
# course_name_third semester spanish                 subject_name_spanish (spanish and portuguese)       0.384986
# facility_code_1480                                 subject_name_nursing                                0.385135
# course_name_momentum and heat transfer operations  instructor_id_2601894.0                             0.385200
# course_name_international trade and finance        instructor_id_2601630.0                             0.385319
# instructor_id_839802.0                             subject_name_astronomy                              0.385450
# subject_name_real estate and urban land economics  course_name_residential property development        0.385450
# course_name_professional communication             instructor_id_3383097.0                             0.385788
# subject_name_french (french and italian)           course_name_first semester french                   0.385909
# facility_code_0028                                 course_name_rhythmic/step aerobics                  0.385936
# instructor_id_4449171.0                            subject_name_military science                       0.386702
# facility_code_0093                                 subject_name_patho-biological sciences              0.387769
# subject_name_industrial and systems engineering    facility_code_0407                                  0.388160
# instructor_id_201172.0                             course_name_organization of information             0.389043
# subject_name_geoscience                            instructor_id_2601758.0                             0.389208
# subject_name_landscape architecture                facility_code_0078                                  0.389354
# subject_name_afro-american studies                 instructor_id_2601801.0                             0.390137
# course_name_field practice and integrative semi... facility_code_0453                                  0.390257
# course_name_foundations of officership             instructor_id_4449171.0                             0.390785
# course_name_musica practica: aural skills 3        section_type_dis                                    0.391826
# course_name_a wisconsin experience seminar         subject_name_counseling psychology                  0.391986
# subject_name_finance, investment and banking       instructor_id_747510.0                              0.393805
# facility_code_0028                                 instructor_id_697108.0                              0.394282
# subject_name_social work                           course_name_field practice and integrative semi...  0.394586
# course_name_relaxation tech & exercise             instructor_id_302280.0                              0.395359
# course_name_first semester russian                 subject_name_slavic (slavic languages)              0.395786
# course_name_creatv wrtng:fic&poetwkshp             instructor_id_201810.0                              0.395875
# course_name_art metal i                            instructor_id_3374761.0                             0.396077
# facility_code_0054                                 subject_name_botany                                 0.396214
# course_name_transitions: practice, professional... subject_name_collaborative nursing program          0.398410
# section_type_lab                                   subject_name_physical educ activity progm           0.398746
# subject_name_philosophy                            course_name_introduction to philosophy              0.399005
# subject_name_accounting and information systems    course_name_introductory financial accounting       0.399397
# subject_name_electrical and computer engineering   instructor_id_566960.0                              0.400626
# facility_code_0044                                 subject_name_nursing                                0.400667
# course_name_second semester portuguese             subject_name_portuguese (spanish and portuguese)    0.401022
# course_name_advanced composition & conversation    instructor_id_3039903.0                             0.402610
# course_name_selected topics in pharmacy practice   subject_name_pharmacy practice                      0.402841
# instructor_id_110350.0                             course_name_online searching for information pr...  0.402949
# instructor_id_520440.0                             subject_name_real estate and urban land economics   0.403395
# instructor_id_3615604.0                            course_name_human resources development: career...  0.403395
# course_name_biomedical engineering design          subject_name_biomedical engineering                 0.404604
# course_name_first-year seminar in the humanities   subject_name_interdisciplinary courses (l&s)        0.404727
# instructor_id_693634.0                             facility_code_0080                                  0.407434
# course_name_tennis i                               instructor_id_618034.0                              0.407898
# instructor_id_3356405.0                            facility_code_0078                                  0.408636
# instructor_id_4916562.0                            course_name_introductory econometrics               0.409249
# instructor_id_2600080.0                            subject_name_linguistics                            0.411697
# subject_name_real estate and urban land economics  course_name_real estate law                         0.412076
# subject_name_microbiology                          instructor_id_807999.0                              0.413674
# course_name_beginning class piano                  subject_name_music-performance                      0.413732
# subject_name_interdisciplinary courses (l&s)       course_name_first-year seminar in the social sc...  0.413827
# subject_name_animal sciences                       course_name_the biology and appreciation of com...  0.414129
# course_name_special topics in integrated libera... instructor_id_215332.0                              0.414693
# subject_name_agricultural and applied economics    instructor_id_2600954.0                             0.415038
# facility_code_0103                                 course_name_foundations of officership              0.416138
# instructor_id_4197612.0                            subject_name_collaborative nursing program          0.416959
# facility_code_0076                                 course_name_science and storytelling                0.417114
# facility_code_0545                                 subject_name_theatre and drama                      0.417465
# instructor_id_4938702.0                            course_name_survey of modern spanish literature     0.417482
# course_name_musica practica: aural skills 2        section_type_dis                                    0.417483
# instructor_id_2602091.0                            course_name_acting realism                          0.417838
# subject_name_human development and family studies  instructor_id_344599.0                              0.418360
# subject_name_afro-american studies                 instructor_id_573312.0                              0.418672
# subject_name_zoology                               instructor_id_2600921.0                             0.419604
# instructor_id_597345.0                             course_name_modernity studies                       0.419680
# subject_name_linguistics                           instructor_id_2602081.0                             0.419773
# subject_name_scandinavian studies                  instructor_id_692771.0                              0.420130
# instructor_id_4189445.0                            course_name_elementary logic                        0.420148
# course_name_tennis ii                              instructor_id_526677.0                              0.421391
# subject_name_neuroscience training program         course_name_undergraduate neurobiology seminar      0.421767
# course_name_photography                            instructor_id_922322.0                              0.422110
# instructor_id_110350.0                             course_name_collection management                   0.422348
# course_name_statics                                subject_name_engineering mechanics and astronau...  0.423739
# instructor_id_2600729.0                            course_name_advanced voice                          0.424030
# subject_name_actuarial science                     course_name_actuarial science methods ii            0.426422
# class_length                                       start_time                                          0.426577
# course_name_problems in educational policy         subject_name_educational policy studies             0.426917
# subject_name_nuclear engineering                   course_name_nuclear reactor laboratory              0.427114
# course_name_musica practica: aural skills 1        section_type_dis                                    0.427317
# course_name_independent reading undergrad          instructor_id_2600039.0                             0.428245
# course_name_reason in communication                instructor_id_2601246.0                             0.428360
# subject_name_sociology                             course_name_topics in sociology                     0.428654
# subject_name_accounting and information systems    facility_code_0140                                  0.429762
# course_name_crc first-year seminar: foundations... instructor_id_4530799.0                             0.431210
# facility_code_0521                                 course_name_evolution and extinction                0.431365
# course_name_introduction to medieval, renaissan... instructor_id_3012375.0                             0.434430
# facility_code_0087a                                subject_name_agronomy                               0.434550
# course_name_fluid mechanics                        instructor_id_3088639.0                             0.434929
# subject_name_medical microbiology and immunology   instructor_id_934395.0                              0.436534
# instructor_id_2600607.0                            subject_name_history of science                     0.436534
# course_name_wes calculus supplement                section_type_dis                                    0.436929
# subject_name_physician assistant program           instructor_id_585086.0                              0.437149
# course_name_sculpture i                            instructor_id_198528.0                              0.438456
# instructor_id_2601788.0                            subject_name_animal sciences                        0.441477
# subject_name_biomedical engineering                course_name_special topics in biomedical engine...  0.441477
# instructor_id_3041045.0                            course_name_spanish civilization                    0.441574
# instructor_id_157057.0                             course_name_technical presentations                 0.443457
# course_name_second semester italian                subject_name_italian (french and italian)           0.443499
# instructor_id_3044764.0                            course_name_civil engineering graphics              0.445570
# instructor_id_4387544.0                            subject_name_naval science                          0.446775
# subject_name_hebrew                                instructor_id_350836.0                              0.447104
# facility_code_0129                                 instructor_id_4387544.0                             0.448653
# instructor_id_685944.0                             subject_name_physician assistant program            0.448817
# course_name_principles of risk management          subject_name_risk management and insurance          0.448978
# instructor_id_2600144.0                            facility_code_0485                                  0.449489
# course_name_current topics in psychology           facility_code_0470                                  0.449581
# course_name_capstone integration seminar           facility_code_0035                                  0.450116
# facility_code_0408                                 subject_name_electrical and computer engineering    0.450255
# section_type_ind                                   course_name_independent study                       0.450323
# instructor_id_106122.0                             subject_name_information systems                    0.450355
# course_name_pilates mat i                          instructor_id_1663711.0                             0.450360
# weekend                                            subject_name_social work                            0.451392
# instructor_id_2601878.0                            subject_name_landscape architecture                 0.451785
# subject_name_philosophy                            course_name_contemporary moral issues               0.452587
# subject_name_zoology                               course_name_topics in biology                       0.453242
# subject_name_religious studies                     course_name_religion in critical perspective        0.453367
# subject_name_comparative literature                course_name_introduction to cross-cultural lite...  0.453558
# subject_name_pharmaceutical sciences               facility_code_0034                                  0.453939
# subject_name_biological systems engineering        instructor_id_693634.0                              0.454100
# instructor_id_5099437.0                            course_name_behavior analysis: applications to ...  0.454301
# subject_name_psychology                            course_name_current topics in psychology            0.454369
# instructor_id_618034.0                             course_name_tennis ii                               0.454566
# facility_code_0025                                 course_name_running (aerobic fitness)               0.454791
# subject_name_agricultural and applied economics    course_name_introduction to agricultural and ap...  0.456251
# instructor_id_135311.0                             subject_name_genetics                               0.458954
# subject_name_languages and cultures of asia - l... instructor_id_4083699.0                             0.459324
# subject_name_art department                        facility_code_0469                                  0.459503
# course_name_actuarial science methods i            subject_name_actuarial science                      0.459549
# subject_name_population health sciences            instructor_id_4162682.0                             0.460344
# instructor_id_2601706.0                            facility_code_0505                                  0.460470
# subject_name_astronomy                             course_name_hands on the universe                   0.460743
# subject_name_spanish (spanish and portuguese)      facility_code_0482                                  0.461710
# facility_code_0220                                 course_name_ceramics i                              0.462016
# subject_name_hebrew                                course_name_second semester hebrew                  0.463194
# instructor_id_4435787.0                            course_name_topics in sociology                     0.463748
# wed                                                fri                                                 0.464109
# course_name_weight training                        instructor_id_2601706.0                             0.466412
# course_name_managing organizations                 subject_name_management and human resources         0.466955
# subject_name_microbiology                          course_name_general microbiology laboratory         0.467338
# subject_name_environmental studies - gaylord ne... course_name_environmental studies major capstone    0.469505
# course_name_the making of modern europe 1500-1815  instructor_id_3013586.0                             0.470505
# course_name_managing organizations                 instructor_id_342827.0                              0.471095
# instructor_id_344599.0                             course_name_stress and resilience in families a...  0.471101
# subject_name_physician assistant program           instructor_id_4841799.0                             0.471380
# course_name_freshman composition                   subject_name_english                                0.472504
# subject_name_portuguese (spanish and portuguese)   course_name_first semester portuguese               0.472676
# course_name_directed study                         section_type_ind                                    0.475638
# course_name_intermediate drawing i                 instructor_id_4232087.0                             0.475827
# subject_name_real estate and urban land economics  instructor_id_810900.0                              0.475863
# course_name_colloquium in art                      instructor_id_2602124.0                             0.476314
# instructor_id_2601900.0                            course_name_introduction to medieval, renaissan...  0.477308
# course_name_derivative securities                  subject_name_finance, investment and banking        0.478149
# instructor_id_777651.0                             course_name_problem solving using computers         0.480061
# instructor_id_636841.0                             course_name_introduction to data structures         0.480750
# subject_name_asian american studies                instructor_id_1017545.0                             0.480868
# course_name_food service operations lab            subject_name_food science                           0.481177
# subject_name_urban and regional planning           instructor_id_2600144.0                             0.481214
# subject_name_comparative literature                instructor_id_3357721.0                             0.481548
# course_name_basic communication                    subject_name_engineering professional development   0.486327
# course_name_advanced seminar in history            subject_name_history                                0.486586
# facility_code_0476                                 subject_name_clinical laboratory science            0.487791
# instructor_id_904512.0                             subject_name_pharmaceutical sciences                0.488170
# course_name_financial reporting i                  instructor_id_498201.0                              0.488591
# subject_name_animal sciences                       facility_code_0118                                  0.490052
# subject_name_occupational therapy (department o... facility_code_0450                                  0.490161
# subject_name_statistics                            course_name_introduction to statistical methods     0.491439
# facility_code_0025                                 course_name_ice skating i                           0.492774
# instructor_id_3357394.0                            subject_name_information systems                    0.493447
# course_name_consumer finance                       instructor_id_631912.0                              0.493748
# facility_code_0450                                 instructor_id_3013999.0                             0.493865
# instructor_id_3555902.0                            course_name_principles of biological anthropology   0.494624
# subject_name_religious studies                     course_name_topics in religious studies - human...  0.494685
# course_name_first semester hebrew                  instructor_id_1062990.0                             0.494763
# facility_code_0018                                 subject_name_english                                0.494939
# subject_name_microbiology                          course_name_biology of microorganisms laboratory    0.494987
# course_name_adapted fitness&pers traing            instructor_id_2601912.0                             0.497284
# subject_name_genetics                              course_name_genetics laboratory                     0.497284
# course_name_real estate finance                    subject_name_real estate and urban land economics   0.497684
# facility_code_0082                                 instructor_id_135311.0                              0.498099
# instructor_id_3013999.0                            course_name_physical therapy educcation and lif...  0.499292
# course_name_special topics in nursing              subject_name_collaborative nursing program          0.499494
# course_name_advanced laboratory                    instructor_id_566960.0                              0.499494
# subject_name_languages and cultures of asia        course_name_topics in languages and cultures of...  0.499571

# %%
# negative low to strong correlations
neg = corr_df[corr_df['coeff'] <= -.3]

with pd.option_context('display.max_rows', None):
    print(neg)
# Out:
#                                                                 coeff
# term_spring                    term_fall                    -1.000000
# section_type_lab               section_type_lec             -0.650262
# course_difficulty_intermediate course_difficulty_elementary -0.632867
# section_type_ind               start_time                   -0.554149
# wed                            tues                         -0.550931
#                                thurs                        -0.518327
# tues                           mon                          -0.499735
# section_type_sem               section_type_lec             -0.466160
# thurs                          mon                          -0.465654
# avg_grade                      f_proportion                 -0.459244
# course_difficulty_elementary   course_difficulty_advanced   -0.437640
# course_difficulty_intermediate course_difficulty_advanced   -0.419209
# section_type_ind               section_type_lec             -0.392251
# section_type_lec               a_proportion                 -0.356340
# subject_name_art department    section_type_lec             -0.337970
# avg_grade                      section_type_lec             -0.331741
# fri                            tues                         -0.322488
# avg_grade                      subject_name_mathematics     -0.309360
# fri                            thurs                        -0.308618
# section_type_ind               class_length                 -0.302928

# %%
## Multivariate exploratory visualizations

# not histograms, boxplots, or correlation plots

df.columns
# Out:
# Index(['section_type', 'instructor_id', 'facility_code', 'start_time', 'mon',
#        'tues', 'wed', 'thurs', 'fri', 'subject_name', 'course_name',
#        'a_proportion', 'f_proportion', 'avg_grade', 'year', 'term',
#        'class_length', 'total_time', 'weekend', 'course_difficulty'],
#       dtype='object')
